# %%
import pandas as pd
import time
from pymongo import MongoClient
from datetime import datetime, timedelta
from konlpy.tag import Okt
from sklearn.feature_extraction.text import TfidfVectorizer
import numpy as np
from collections import OrderedDict

# %%
# MongoDB 접속 정보
user = "mango"
password = "sweetmango123"
host = "j10e204.p.ssafy.io"  # 또는 MongoDB가 실행되고 있는 서버의 주소
port = 27017
dbname = "mango"  # 접속하고자 하는 데이터베이스 이름

# MongoDB URI 구성
uri = f"mongodb://{user}:{password}@{host}:{port}"

# MongoDB 클라이언트 생성
client = MongoClient(uri)

# 데이터베이스 선택
db = client[dbname]
# 접속 테스트를 위한 컬렉션 및 데이터 출력 예시
collection = db["news"]  # 사용할 컬렉션 이름

# %%
# 오늘 날짜와 정확히 1년 전 날짜 계산
today = datetime.now().replace(hour=0, minute=0, second=0, microsecond=0)
one_year_ago = today - timedelta(days=366)

# 날짜를 "YYYY-MM-DD" 형식의 문자열로 변환
one_year_ago_str = one_year_ago.strftime("%Y-%m-%d")

# 쿼리 실행 전 시간 측정
start_time = time.time()

## published 필드 기준으로 인덱싱
# collection.create_index([("published", 1)])
# 문자열 기반으로 1년 전 날짜에 해당하는 기사 조회
last_year_news = list(collection.find({"published": {"$regex": f"^{one_year_ago_str}"}}, {"title": 1, "_id": 0}))
# 뉴스 데이터의 'article' 필드만 추출하여 리스트 생성
titles = [news['title'] for news in last_year_news if 'title' in news]
print(len(titles))
# 쿼리 실행 후 시간 측정
end_time = time.time()
# 실행 시간 출력
print(f"쿼리 실행 시간: {end_time - start_time}초")
# Out:
# 7144
# 쿼리 실행 시간: 0.3420555591583252초

# %%
unique_titles = list(OrderedDict.fromkeys(titles))

# %%
len(unique_titles)
# Out:
# 6006

# %% [markdown]
# ## 불용어 불러오기

# %%
file_path = 'korean_stopwords.txt'  # 여기에 파일 경로를 입력하세요
with open(file_path, 'r', encoding='utf-8') as file:
    # 파일 내용 읽기
    content = file.read()
stopwords = content.strip().split('\n')
stopwords
# Out:
# ['아',
#  '휴',
#  '아이구',
#  '아이쿠',
#  '아이고',
#  '어',
#  '나',
#  '우리',
#  '저희',
#  '따라',
#  '의해',
#  '을',
#  '를',
#  '에',
#  '의',
#  '가',
#  '으로',
#  '로',
#  '에게',
#  '뿐이다',
#  '의거하여',
#  '근거하여',
#  '입각하여',
#  '기준으로',
#  '예하면',
#  '예를 들면',
#  '예를 들자면',
#  '저',
#  '소인',
#  '소생',
#  '저희',
#  '지말고',
#  '하지마',
#  '하지마라',
#  '다른',
#  '물론',
#  '또한',
#  '그리고',
#  '비길수 없다',
#  '해서는 안된다',
#  '뿐만 아니라',
#  '만이 아니다',
#  '만은 아니다',
#  '막론하고',
#  '관계없이',
#  '그치지 않다',
#  '그러나',
#  '그런데',
#  '하지만',
#  '든간에',
#  '논하지 않다',
#  '따지지 않다',
#  '설사',
#  '비록',
#  '더라도',
#  '아니면',
#  '만 못하다',
#  '하는 편이 낫다',
#  '불문하고',
#  '향하여',
#  '향해서',
#  '향하다',
#  '쪽으로',
#  '틈타',
#  '이용하여',
#  '타다',
#  '오르다',
#  '제외하고',
#  '이 외에',
#  '이 밖에',
#  '하여야',
#  '비로소',
#  '한다면 몰라도',
#  '외에도',
#  '이곳',
#  '여기',
#  '부터',
#  '기점으로',
#  '따라서',
#  '할 생각이다',
#  '하려고하다',
#  '이리하여',
#  '그리하여',
#  '그렇게 함으로써',
#  '하지만',
#  '일때',
#  '할때',
#  '앞에서',
#  '중에서',
#  '보는데서',
#  '으로써',
#  '로써',
#  '까지',
#  '해야한다',
#  '일것이다',
#  '반드시',
#  '할줄알다',
#  '할수있다',
#  '할수있어',
#  '임에 틀림없다',
#  '한다면',
#  '등',
#  '등등',
#  '제',
#  '겨우',
#  '단지',
#  '다만',
#  '할뿐',
#  '딩동',
#  '댕그',
#  '대해서',
#  '대하여',
#  '대하면',
#  '훨씬',
#  '얼마나',
#  '얼마만큼',
#  '얼마큼',
#  '남짓',
#  '여',
#  '얼마간',
#  '약간',
#  '다소',
#  '좀',
#  '조금',
#  '다수',
#  '몇',
#  '얼마',
#  '지만',
#  '하물며',
#  '또한',
#  '그러나',
#  '그렇지만',
#  '하지만',
#  '이외에도',
#  '대해 말하자면',
#  '뿐이다',
#  '다음에',
#  '반대로',
#  '반대로 말하자면',
#  '이와 반대로',
#  '바꾸어서 말하면',
#  '바꾸어서 한다면',
#  '만약',
#  '그렇지않으면',
#  '까악',
#  '툭',
#  '딱',
#  '삐걱거리다',
#  '보드득',
#  '비걱거리다',
#  '꽈당',
#  '응당',
#  '해야한다',
#  '에 가서',
#  '각',
#  '각각',
#  '여러분',
#  '각종',
#  '각자',
#  '제각기',
#  '하도록하다',
#  '와',
#  '과',
#  '그러므로',
#  '그래서',
#  '고로',
#  '한 까닭에',
#  '하기 때문에',
#  '거니와',
#  '이지만',
#  '대하여',
#  '관하여',
#  '관한',
#  '과연',
#  '실로',
#  '아니나다를가',
#  '생각한대로',
#  '진짜로',
#  '한적이있다',
#  '하곤하였다',
#  '하',
#  '하하',
#  '허허',
#  '아하',
#  '거바',
#  '와',
#  '오',
#  '왜',
#  '어째서',
#  '무엇때문에',
#  '어찌',
#  '하겠는가',
#  '무슨',
#  '어디',
#  '어느곳',
#  '더군다나',
#  '하물며',
#  '더욱이는',
#  '어느때',
#  '언제',
#  '야',
#  '이봐',
#  '어이',
#  '여보시오',
#  '흐흐',
#  '흥',
#  '휴',
#  '헉헉',
#  '헐떡헐떡',
#  '영차',
#  '여차',
#  '어기여차',
#  '끙끙',
#  '아야',
#  '앗',
#  '아야',
#  '콸콸',
#  '졸졸',
#  '좍좍',
#  '뚝뚝',
#  '주룩주룩',
#  '솨',
#  '우르르',
#  '그래도',
#  '또',
#  '그리고',
#  '바꾸어말하면',
#  '바꾸어말하자면',
#  '혹은',
#  '혹시',
#  '답다',
#  '및',
#  '그에 따르는',
#  '때가 되어',
#  '즉',
#  '지든지',
#  '설령',
#  '가령',
#  '하더라도',
#  '할지라도',
#  '일지라도',
#  '지든지',
#  '몇',
#  '거의',
#  '하마터면',
#  '인젠',
#  '이젠',
#  '된바에야',
#  '된이상',
#  '만큼\t어찌됏든',
#  '그위에',
#  '게다가',
#  '점에서 보아',
#  '비추어 보아',
#  '고려하면',
#  '하게될것이다',
#  '일것이다',
#  '비교적',
#  '좀',
#  '보다더',
#  '비하면',
#  '시키다',
#  '하게하다',
#  '할만하다',
#  '의해서',
#  '연이서',
#  '이어서',
#  '잇따라',
#  '뒤따라',
#  '뒤이어',
#  '결국',
#  '의지하여',
#  '기대여',
#  '통하여',
#  '자마자',
#  '더욱더',
#  '불구하고',
#  '얼마든지',
#  '마음대로',
#  '주저하지 않고',
#  '곧',
#  '즉시',
#  '바로',
#  '당장',
#  '하자마자',
#  '밖에 안된다',
#  '하면된다',
#  '그래',
#  '그렇지',
#  '요컨대',
#  '다시 말하자면',
#  '바꿔 말하면',
#  '즉',
#  '구체적으로',
#  '말하자면',
#  '시작하여',
#  '시초에',
#  '이상',
#  '허',
#  '헉',
#  '허걱',
#  '바와같이',
#  '해도좋다',
#  '해도된다',
#  '게다가',
#  '더구나',
#  '하물며',
#  '와르르',
#  '팍',
#  '퍽',
#  '펄렁',
#  '동안',
#  '이래',
#  '하고있었다',
#  '이었다',
#  '에서',
#  '로부터',
#  '까지',
#  '예하면',
#  '했어요',
#  '해요',
#  '함께',
#  '같이',
#  '더불어',
#  '마저',
#  '마저도',
#  '양자',
#  '모두',
#  '습니다',
#  '가까스로',
#  '하려고하다',
#  '즈음하여',
#  '다른',
#  '다른 방면으로',
#  '해봐요',
#  '습니까',
#  '했어요',
#  '말할것도 없고',
#  '무릎쓰고',
#  '개의치않고',
#  '하는것만 못하다',
#  '하는것이 낫다',
#  '매',
#  '매번',
#  '들',
#  '모',
#  '어느것',
#  '어느',
#  '로써',
#  '갖고말하자면',
#  '어디',
#  '어느쪽',
#  '어느것',
#  '어느해',
#  '어느 년도',
#  '라 해도',
#  '언젠가',
#  '어떤것',
#  '어느것',
#  '저기',
#  '저쪽',
#  '저것',
#  '그때',
#  '그럼',
#  '그러면',
#  '요만한걸',
#  '그래',
#  '그때',
#  '저것만큼',
#  '그저',
#  '이르기까지',
#  '할 줄 안다',
#  '할 힘이 있다',
#  '너',
#  '너희',
#  '당신',
#  '어찌',
#  '설마',
#  '차라리',
#  '할지언정',
#  '할지라도',
#  '할망정',
#  '할지언정',
#  '구토하다',
#  '게우다',
#  '토하다',
#  '메쓰겁다',
#  '옆사람',
#  '퉤',
#  '쳇',
#  '의거하여',
#  '근거하여',
#  '의해',
#  '따라',
#  '힘입어',
#  '그',
#  '다음',
#  '버금',
#  '두번째로',
#  '기타',
#  '첫번째로',
#  '나머지는',
#  '그중에서',
#  '견지에서',
#  '형식으로 쓰여',
#  '입장에서',
#  '위해서',
#  '단지',
#  '의해되다',
#  '하도록시키다',
#  '뿐만아니라',
#  '반대로',
#  '전후',
#  '전자',
#  '앞의것',
#  '잠시',
#  '잠깐',
#  '하면서',
#  '그렇지만',
#  '다음에',
#  '그러한즉',
#  '그런즉',
#  '남들',
#  '아무거나',
#  '어찌하든지',
#  '같다',
#  '비슷하다',
#  '예컨대',
#  '이럴정도로',
#  '어떻게',
#  '만약',
#  '만일',
#  '위에서 서술한바와같이',
#  '인 듯하다',
#  '하지 않는다면',
#  '만약에',
#  '무엇',
#  '무슨',
#  '어느',
#  '어떤',
#  '아래윗',
#  '조차',
#  '한데',
#  '그럼에도 불구하고',
#  '여전히',
#  '심지어',
#  '까지도',
#  '조차도',
#  '하지 않도록',
#  '않기 위하여',
#  '때',
#  '시각',
#  '무렵',
#  '시간',
#  '동안',
#  '어때',
#  '어떠한',
#  '하여금',
#  '네',
#  '예',
#  '우선',
#  '누구',
#  '누가 알겠는가',
#  '아무도',
#  '줄은모른다',
#  '줄은 몰랏다',
#  '하는 김에',
#  '겸사겸사',
#  '하는바',
#  '그런 까닭에',
#  '한 이유는',
#  '그러니',
#  '그러니까',
#  '때문에',
#  '그',
#  '너희',
#  '그들',
#  '너희들',
#  '타인',
#  '것',
#  '것들',
#  '너',
#  '위하여',
#  '공동으로',
#  '동시에',
#  '하기 위하여',
#  '어찌하여',
#  '무엇때문에',
#  '붕붕',
#  '윙윙',
#  '나',
#  '우리',
#  '엉엉',
#  '휘익',
#  '윙윙',
#  '오호',
#  '아하',
#  '어쨋든',
#  '만 못하다\t하기보다는',
#  '차라리',
#  '하는 편이 낫다',
#  '흐흐',
#  '놀라다',
#  '상대적으로 말하자면',
#  '마치',
#  '아니라면',
#  '쉿',
#  '그렇지 않으면',
#  '그렇지 않다면',
#  '안 그러면',
#  '아니었다면',
#  '하든지',
#  '아니면',
#  '이라면',
#  '좋아',
#  '알았어',
#  '하는것도',
#  '그만이다',
#  '어쩔수 없다',
#  '하나',
#  '일',
#  '일반적으로',
#  '일단',
#  '한켠으로는',
#  '오자마자',
#  '이렇게되면',
#  '이와같다면',
#  '전부',
#  '한마디',
#  '한항목',
#  '근거로',
#  '하기에',
#  '아울러',
#  '하지 않도록',
#  '않기 위해서',
#  '이르기까지',
#  '이 되다',
#  '로 인하여',
#  '까닭으로',
#  '이유만으로',
#  '이로 인하여',
#  '그래서',
#  '이 때문에',
#  '그러므로',
#  '그런 까닭에',
#  '알 수 있다',
#  '결론을 낼 수 있다',
#  '으로 인하여',
#  '있다',
#  '어떤것',
#  '관계가 있다',
#  '관련이 있다',
#  '연관되다',
#  '어떤것들',
#  '에 대해',
#  '이리하여',
#  '그리하여',
#  '여부',
#  '하기보다는',
#  '하느니',
#  '하면 할수록',
#  '운운',
#  '이러이러하다',
#  '하구나',
#  '하도다',
#  '다시말하면',
#  '다음으로',
#  '에 있다',
#  '에 달려 있다',
#  '우리',
#  '우리들',
#  '오히려',
#  '하기는한데',
#  '어떻게',
#  '어떻해',
#  '어찌됏어',
#  '어때',
#  '어째서',
#  '본대로',
#  '자',
#  '이',
#  '이쪽',
#  '여기',
#  '이것',
#  '이번',
#  '이렇게말하자면',
#  '이런',
#  '이러한',
#  '이와 같은',
#  '요만큼',
#  '요만한 것',
#  '얼마 안 되는 것',
#  '이만큼',
#  '이 정도의',
#  '이렇게 많은 것',
#  '이와 같다',
#  '이때',
#  '이렇구나',
#  '것과 같이',
#  '끼익',
#  '삐걱',
#  '따위',
#  '와 같은 사람들',
#  '부류의 사람들',
#  '왜냐하면',
#  '중의하나',
#  '오직',
#  '오로지',
#  '에 한하다',
#  '하기만 하면',
#  '도착하다',
#  '까지 미치다',
#  '도달하다',
#  '정도에 이르다',
#  '할 지경이다',
#  '결과에 이르다',
#  '관해서는',
#  '여러분',
#  '하고 있다',
#  '한 후',
#  '혼자',
#  '자기',
#  '자기집',
#  '자신',
#  '우에 종합한것과같이',
#  '총적으로 보면',
#  '총적으로 말하면',
#  '총적으로',
#  '대로 하다',
#  '으로서',
#  '참',
#  '그만이다',
#  '할 따름이다',
#  '쿵',
#  '탕탕',
#  '쾅쾅',
#  '둥둥',
#  '봐',
#  '봐라',
#  '아이야',
#  '아니',
#  '와아',
#  '응',
#  '아이',
#  '참나',
#  '년',
#  '월',
#  '일',
#  '령',
#  '영',
#  '일',
#  '이',
#  '삼',
#  '사',
#  '오',
#  '육',
#  '륙',
#  '칠',
#  '팔',
#  '구',
#  '이천육',
#  '이천칠',
#  '이천팔',
#  '이천구',
#  '하나',
#  '둘',
#  '셋',
#  '넷',
#  '다섯',
#  '여섯',
#  '일곱',
#  '여덟',
#  '아홉',
#  '령',
#  '영',
#  '기자',
#  '<',
#  '>',
#  '▲',
#  '·',
#  '이',
#  '의',
#  '를',
#  '은',
#  '로',
#  '것',
#  '과',
#  '도',
#  '등',
#  '고']

# %%
# 뉴스 본문에서 불용어 제거
cleaned_titles = []
for title in unique_titles:
    words = title.split()  # 공백 기준으로 단어 분리
    filtered_words = [word for word in words if word not in stopwords]  # 불용어가 아닌 단어만 선택
    cleaned_title = ' '.join(filtered_words)  # 정제된 단어들을 다시 문자열로 결합
    cleaned_titles.append(cleaned_title)

# %%
cleaned_titles[0]
# Out:
# '국보법 위반, 5범 후보…‘전과‘에 몸살 앓는 4·5 재보선'

# %%
tfidf_vectorizer = TfidfVectorizer()

# TF-IDF 계산
tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_titles)

# 각 단어의 TF-IDF 점수를 기준으로 정렬하여 상위 N개 키워드 추출
def extract_top_n_keywords(tfidf_matrix, feature_names, n=10):
    # 각 기사별로 반복
    for i in range(tfidf_matrix.shape[0]):
        # 해당 기사의 모든 단어의 TF-IDF 점수 추출
        scores = tfidf_matrix[i].toarray().flatten()
        # 점수에 따라 단어 인덱스 정렬
        sorted_indices = np.argsort(scores)[::-1]
        top_n_indices = sorted_indices[:n]
        # 상위 N개 키워드와 그 점수 출력
        print(f"Article {i+1} Top-{n} keywords:")
        for index in top_n_indices:
            print(f"{feature_names[index]} ({scores[index]:.4f})")
        print("\n")

# TF-IDF 벡터라이저에서 단어 목록 추출
feature_names = np.array(tfidf_vectorizer.get_feature_names_out())

# 상위 N개 키워드 추출 함수 호출
extract_top_n_keywords(tfidf_matrix, feature_names, n=10)
# Out:
# Article 1 Top-10 keywords:
# 5범 (0.3801)
# 재보선 (0.3801)
# 앓는 (0.3801)
# 국보법 (0.3801)
# 전과 (0.3630)
# 몸살 (0.3630)
# 위반 (0.2980)
# 후보 (0.2644)
# 들려온다 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 2 Top-10 keywords:
# 원한다 (0.3787)
# 키워 (0.3617)
# 세상보다 (0.3617)
# 키울 (0.3496)
# 세상 (0.3402)
# 주는 (0.3325)
# 내가 (0.3070)
# 사설 (0.2913)
# 있는 (0.2596)
# 두자릿수 (0.0000)
#
#
# Article 3 Top-10 keywords:
# 배터리 (0.5172)
# 굴기 (0.3474)
# 美에 (0.3474)
# 맞설 (0.3317)
# 기지로 (0.3317)
# lg엔솔 (0.2939)
# 사설 (0.2672)
# 공장 (0.2606)
# 최대 (0.2131)
# 둘러싼 (0.0000)
#
#
# Article 4 Top-10 keywords:
# 받겠다는 (0.4236)
# mz노조 (0.4045)
# 보조금 (0.4045)
# 맞다 (0.4045)
# 이게 (0.3805)
# 사설 (0.3258)
# 정부 (0.2804)
# 李대표 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 5 Top-10 keywords:
# 순국 (0.4432)
# 113주기 (0.4432)
# 안중근 (0.4284)
# 의사 (0.4075)
# 추모식 (0.4075)
# 포토 (0.3025)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 6 Top-10 keywords:
# 추위 (0.4202)
# 보통 (0.4202)
# 반짝 (0.4120)
# 미세먼지 (0.3681)
# 아침 (0.3649)
# 오늘의 (0.3403)
# 날씨 (0.3045)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 7 Top-10 keywords:
# 느껴지면 (0.3988)
# 계절성 (0.3988)
# 타나 (0.3988)
# 주의보 (0.3809)
# 조심 (0.3681)
# 우울증 (0.3583)
# 나도 (0.3374)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 8 Top-10 keywords:
# 부글부글 (0.4082)
# 강일홍의 (0.4082)
# 연예인들 (0.4082)
# 가짜뉴스 (0.4082)
# 클로즈업 (0.4082)
# 마구잡이 (0.4082)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 9 Top-10 keywords:
# 먼지만 (0.4122)
# 방치할 (0.4122)
# 법안들 (0.4122)
# 이대로 (0.4122)
# 건가 (0.3703)
# 학폭 (0.3046)
# 관련 (0.3005)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 10 Top-10 keywords:
# 이재명표 (0.4612)
# 물음표 (0.4405)
# 쇄신 (0.4143)
# 퇴진론 (0.3903)
# 빠진 (0.3842)
# 비명계 (0.3487)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 11 Top-10 keywords:
# 제일약품 (0.3840)
# 성석제 (0.3840)
# 7연임 (0.3840)
# 신성장동력 (0.3667)
# 실적 (0.3371)
# 성공 (0.3010)
# 개선 (0.2903)
# 확보 (0.2746)
# 대표 (0.2435)
# 뒷불 (0.0000)
#
#
# Article 12 Top-10 keywords:
# 철강업계 (0.3700)
# 온도차 (0.3700)
# 어렵 (0.3700)
# 후판값 (0.3700)
# 인하 (0.3533)
# 조선 (0.3415)
# 협상 (0.3248)
# 여전 (0.3248)
# 드디어 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 13 Top-10 keywords:
# 리멤버 (0.3946)
# 별을 (0.3946)
# 추억하며 (0.3946)
# 해피 (0.3946)
# 투게더 (0.3946)
# 장국영 (0.3768)
# 다시 (0.2822)
# 뒷불 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 14 Top-10 keywords:
# 고지 (0.4818)
# 연합뉴스 (0.4657)
# 알림 (0.4532)
# 저작권 (0.4269)
# 콘텐츠 (0.4042)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 15 Top-10 keywords:
# 낮아져 (0.4413)
# 기온의 (0.4073)
# 어제보다 (0.4073)
# 크게 (0.3964)
# 아침 (0.3364)
# 기온 (0.3285)
# 일교차 (0.3086)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 16 Top-10 keywords:
# 주고받는 (0.3809)
# 협력만 (0.3809)
# 포퓰리즘 (0.3809)
# 건가 (0.3421)
# tk (0.3421)
# 공항 (0.3128)
# 여야 (0.2957)
# 사설 (0.2930)
# 광주 (0.2439)
# 李대표 (0.0000)
#
#
# Article 17 Top-10 keywords:
# 짜라 (0.3645)
# 첫째아 (0.3523)
# 비중 (0.3286)
# 전략 (0.3230)
# 국가 (0.3230)
# 출생아 (0.3230)
# 인구 (0.3058)
# 사설 (0.2936)
# 다시 (0.2730)
# 최고 (0.2604)
#
#
# Article 18 Top-10 keywords:
# 가계 (0.3409)
# 없도록 (0.3409)
# 선제적으로 (0.3409)
# 부채 (0.3409)
# 점검해야 (0.3409)
# pf (0.3147)
# 연쇄 (0.3147)
# 부실 (0.2840)
# 부동산 (0.2673)
# 사설 (0.2622)
#
#
# Article 19 Top-10 keywords:
# 없습니다 (0.3129)
# 운세 (0.2747)
# 2023년 (0.2200)
# 3월 (0.1978)
# 겁니다 (0.1564)
# 84년 (0.1564)
# 갑자생 (0.1564)
# 무너질 (0.1564)
# 무자생 (0.1564)
# 정동근 (0.1564)
#
#
# Article 20 Top-10 keywords:
# 뉴스1 (0.3906)
# 콘텐츠 (0.2631)
# 콘텐츠는 (0.1642)
# 보호를 (0.1642)
# 그래픽 (0.1642)
# 따를 (0.1642)
# 저작권법을 (0.1642)
# 뉴스1이 (0.1642)
# 전재 (0.1642)
# 사용에 (0.1642)
#
#
# Article 21 Top-10 keywords:
# 매달려 (0.3702)
# 더듬이 (0.3702)
# 글에 (0.3702)
# 이어령 (0.3702)
# 그에겐 (0.3702)
# 평생 (0.3535)
# 있었다 (0.3250)
# 도전 (0.2902)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 22 Top-10 keywords:
# 삶과 (0.4030)
# 추억 (0.4030)
# 실리콘밸리 (0.3895)
# 무어의 (0.3790)
# 법칙 (0.3705)
# 전설 (0.3705)
# 만든 (0.3245)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 23 Top-10 keywords:
# 김종찬씨 (0.7838)
# 부고 (0.6210)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 24 Top-10 keywords:
# 신병확보 (0.5779)
# 경쟁 (0.5041)
# 권도형 (0.4539)
# 테라 (0.4539)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 25 Top-10 keywords:
# 선발 (0.4242)
# 국가수사본부장에 (0.3879)
# 낙마 (0.3741)
# 내부 (0.3632)
# 내정 (0.3601)
# 우종수 (0.3179)
# 정순신 (0.3079)
# 경찰 (0.2687)
# 李대표 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 26 Top-10 keywords:
# 잠재울까 (0.5474)
# 퇴진론 (0.4631)
# 당직개편 (0.4560)
# 이번주 (0.4249)
# 이재명 (0.3121)
# 뒷동산서 (0.0000)
# 두산에너빌리티 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 27 Top-10 keywords:
# 리창경제팀 (0.4159)
# 제도적 (0.4159)
# 글로벌ceo (0.3972)
# 상견례 (0.3972)
# 시진핑 (0.3736)
# 개방 (0.3464)
# 확대 (0.2812)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 28 Top-10 keywords:
# 뉴스타트 (0.4535)
# 전진배치 (0.4331)
# 중단 (0.3633)
# 벨라루스에 (0.3593)
# 푸틴 (0.3521)
# 핵무기 (0.3376)
# 이어 (0.3284)
# 뒷불 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 29 Top-10 keywords:
# 금융위험 (0.4462)
# 상업용부동산 (0.4462)
# 7280조원 (0.4462)
# 대출 (0.3297)
# 이어 (0.3231)
# 은행 (0.3231)
# 미국 (0.2920)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 30 Top-10 keywords:
# 82년 (0.4180)
# 대만과 (0.3858)
# 중국이 (0.3858)
# 유일 (0.3755)
# 단교 (0.3670)
# 온두라스 (0.3433)
# 정부 (0.2767)
# 만에 (0.2398)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 31 Top-10 keywords:
# 안보균형 (0.4262)
# 핵카드 (0.4262)
# view (0.4262)
# 동북아 (0.4070)
# 연쇄 (0.3934)
# 위협 (0.3669)
# 두었던 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 32 Top-10 keywords:
# 운세 (0.6419)
# 오늘의 (0.5198)
# 3월 (0.4620)
# 27일 (0.3230)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 33 Top-10 keywords:
# 원성 (0.3708)
# 가라 (0.3708)
# 찌르는 (0.3708)
# 즐거웠다 (0.3708)
# 하늘 (0.3541)
# 3만원 (0.3423)
# 그동안 (0.3423)
# 치킨 (0.3006)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 34 Top-10 keywords:
# 아트허브 (0.4295)
# 홍콩의 (0.4295)
# 귀환 (0.4295)
# 수십억 (0.4102)
# 쏟아졌다 (0.3964)
# 거래 (0.3482)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 35 Top-10 keywords:
# 독일의 (0.4144)
# 지휘자 (0.4144)
# 보헤미안 (0.4144)
# 사운드 (0.4144)
# 체코 (0.3957)
# 만났다 (0.3957)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 36 Top-10 keywords:
# 오늘의 (0.5796)
# 날씨 (0.5186)
# 3월 (0.5152)
# 27일 (0.3602)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 37 Top-10 keywords:
# 7연속 (0.5408)
# 국제장애인기능올림픽 (0.5408)
# 우승 (0.3941)
# 사진 (0.3782)
# 한국 (0.3418)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 38 Top-10 keywords:
# 오늘은 (0.4715)
# 반짝 (0.4250)
# 꽃샘추위 (0.4177)
# 주말 (0.3955)
# 벚꽃 (0.3833)
# 사진 (0.3453)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 39 Top-10 keywords:
# 피격 (0.4529)
# 발길 (0.4325)
# 천안함 (0.4180)
# 13주기 (0.4180)
# 추모 (0.3976)
# 사진 (0.3167)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 40 Top-10 keywords:
# 남자피겨 (0.4710)
# 은메달 (0.4347)
# 세계선수권 (0.3692)
# 최초 (0.3591)
# 차준환 (0.3561)
# 사진 (0.3294)
# 한국 (0.2977)
# 李대표 (0.0000)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 41 Top-10 keywords:
# 몸처럼 (0.4027)
# 태극 (0.4027)
# 1장 (0.4027)
# 1만2263명 (0.3846)
# 신기록 (0.3846)
# 품새 (0.3718)
# 세계 (0.2817)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 42 Top-10 keywords:
# 골잡이 (0.4049)
# 원톱 (0.4049)
# 3인 (0.4049)
# 앞에서 (0.4049)
# 공격수 (0.3867)
# 경쟁 (0.3373)
# 감독 (0.2847)
# 듀피젠트 (0.0000)
# 드디어 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 43 Top-10 keywords:
# 삼성화재배 (0.3957)
# 해설 (0.3957)
# ai와 (0.3957)
# 바둑 (0.3957)
# 필사의 (0.3957)
# 함께하는 (0.3554)
# 탈출 (0.3016)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 44 Top-10 keywords:
# 몸은 (0.4359)
# 따라주더라 (0.4359)
# 힘으로 (0.4359)
# 과학 (0.4024)
# 연기 (0.3689)
# 30대 (0.3632)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 45 Top-10 keywords:
# 중앙음악콩쿠르 (0.4720)
# 경연 (0.4508)
# 알림 (0.4240)
# 본선 (0.4144)
# 29 (0.3418)
# 31일 (0.3251)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 46 Top-10 keywords:
# 쓸까 (0.6700)
# 붙여 (0.3350)
# 우리말 (0.3350)
# 띄어 (0.3350)
# 바루기 (0.3350)
# 걸까 (0.3199)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 47 Top-10 keywords:
# 대환 (0.3927)
# kb국민은행 (0.3625)
# 2금융권 (0.3448)
# now (0.3381)
# 상품 (0.3381)
# biz (0.3322)
# 신용대출 (0.3322)
# 대출 (0.2902)
# 출시 (0.2490)
# 뒷면에는 (0.0000)
#
#
# Article 48 Top-10 keywords:
# 이스타항공 (0.4345)
# now (0.4165)
# biz (0.4093)
# 운항 (0.3973)
# 재개 (0.3440)
# 3년 (0.3420)
# 만에 (0.2776)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 49 Top-10 keywords:
# 전구체 (0.3603)
# 10만t (0.3603)
# 새만금에 (0.3603)
# 2조원 (0.3440)
# 들여 (0.3440)
# 짓는다 (0.3440)
# 연산 (0.3325)
# 공장 (0.2702)
# 배터리 (0.2682)
# 뒷동산 (0.0000)
#
#
# Article 50 Top-10 keywords:
# 역사적 (0.3510)
# 이겨내는 (0.3510)
# 비즈 (0.3510)
# 유치는 (0.3510)
# 필연 (0.3510)
# 부산의 (0.3352)
# 칼럼 (0.3240)
# 엑스포 (0.2924)
# 도시 (0.2846)
# 뒷받침 (0.0000)
#
#
# Article 51 Top-10 keywords:
# 바다의 (0.3776)
# 수협회장 (0.3776)
# 노동진 (0.3485)
# 만들겠다 (0.3392)
# 쿠팡 (0.3315)
# now (0.3251)
# biz (0.3195)
# 취임 (0.2931)
# 신임 (0.2734)
# 뒷동산서 (0.0000)
#
#
# Article 52 Top-10 keywords:
# ai인재 (0.3531)
# 33개팀 (0.3372)
# 해커톤 (0.3372)
# 열어 (0.3100)
# 대회 (0.3040)
# now (0.3040)
# biz (0.2988)
# 참가 (0.2797)
# 양성 (0.2797)
# lg (0.2768)
#
#
# Article 53 Top-10 keywords:
# 로또 (0.5006)
# 복권 (0.5006)
# 제1060회 (0.5006)
# 24일 (0.3850)
# 3월 (0.3164)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 54 Top-10 keywords:
# x같은 (0.3979)
# 뜬금없이 (0.3979)
# 욕설을 (0.3979)
# ai챗봇이 (0.3979)
# 살기 (0.3673)
# 서울서 (0.3574)
# 했다 (0.3226)
# 뒷받침 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 55 Top-10 keywords:
# 마용성 (0.4952)
# 낸다 (0.4571)
# 59 (0.4067)
# 종부세 (0.3967)
# 아파트 (0.3521)
# 올해 (0.3150)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 56 Top-10 keywords:
# 이중과세 (0.4322)
# 없앴더니 (0.4322)
# 유보금이 (0.4322)
# 쌓아뒀던 (0.4322)
# 돌아왔다 (0.3883)
# 해외 (0.3194)
# 두자릿수 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 두살 (0.0000)
#
#
# Article 57 Top-10 keywords:
# wgbi (0.3862)
# 저평가된 (0.3862)
# 편입은 (0.3862)
# 언제 (0.3689)
# 채권 (0.3689)
# msci (0.3565)
# 주식 (0.3060)
# 한국 (0.2441)
# 뒤쪽의 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 58 Top-10 keywords:
# 떨어졌다 (0.4202)
# 한국도 (0.4013)
# 금융주 (0.4013)
# 이달 (0.3500)
# 들어 (0.3500)
# 하락 (0.3128)
# 30 (0.2880)
# 미국 (0.2749)
# 듀엣곡 (0.0000)
# 듀피젠트 (0.0000)
#
#
# Article 59 Top-10 keywords:
# data (0.4103)
# 임금 (0.3603)
# now (0.3532)
# 평균 (0.3370)
# 근로자 (0.3327)
# 코로나 (0.3327)
# 상승 (0.3156)
# 3년 (0.2901)
# 10 (0.2417)
# 드디어 (0.0000)
#
#
# Article 60 Top-10 keywords:
# 공장부터 (0.4139)
# 핵심부품 (0.4139)
# 챙겼다 (0.3953)
# 자율차 (0.3953)
# 방중 (0.3502)
# 3년만에 (0.3502)
# 이재용 (0.3156)
# 뒷동산 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 61 Top-10 keywords:
# 재개된 (0.5001)
# 상하이 (0.4006)
# 노선 (0.3723)
# 3년 (0.3536)
# 사진 (0.3498)
# 제주 (0.3479)
# 만에 (0.2869)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 62 Top-10 keywords:
# 번으로 (0.3648)
# 수많은 (0.3648)
# 전자제품 (0.3648)
# 동작하도록 (0.3648)
# 버튼 (0.3484)
# 기능 (0.3203)
# 하는 (0.3039)
# 디자인 (0.2923)
# ai (0.2565)
# 뒷불 (0.0000)
#
#
# Article 63 Top-10 keywords:
# 하필 (0.3694)
# 감세정책 (0.3694)
# 폈는데 (0.3694)
# 9조 (0.3694)
# 불경기 (0.3694)
# 세수 (0.3527)
# 한해 (0.3527)
# 12 (0.2626)
# 듀엣곡 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 64 Top-10 keywords:
# 2년5개월 (0.4131)
# 조국 (0.4131)
# 3년2개월 (0.4131)
# 시간은 (0.3945)
# 윤미향 (0.3813)
# 법정 (0.3627)
# 이재명 (0.2356)
# 뒷받침했다 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 65 Top-10 keywords:
# 구강 (0.3280)
# 높여 (0.3280)
# 만족도 (0.3280)
# 고려한 (0.3280)
# 임플란트 (0.3280)
# 개인별 (0.3132)
# 질병 (0.3132)
# 맞춤형 (0.2694)
# 건강한 (0.2628)
# 고객 (0.2523)
#
#
# Article 66 Top-10 keywords:
# 나눔서 (0.3513)
# 방역까지 (0.3513)
# 피부병부터 (0.3513)
# 영향력은 (0.3513)
# 선한 (0.3354)
# 장병 (0.3242)
# 코로나 (0.2848)
# 건강한 (0.2814)
# 가족 (0.2635)
# 시작 (0.2431)
#
#
# Article 67 Top-10 keywords:
# 오해했다 (0.3858)
# 신부전 (0.3858)
# 떨어뜨리는 (0.3858)
# 요실금 (0.3858)
# 이놈 (0.3858)
# 부른다 (0.3684)
# 삶의 (0.3465)
# 듀엣곡 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 68 Top-10 keywords:
# 어취 (0.3541)
# 챙겨 (0.3541)
# 줄인 (0.3541)
# 알티지 (0.3541)
# 혈행 (0.3541)
# 오메가3로 (0.3541)
# 건강 (0.3109)
# 건강한 (0.2837)
# 가족 (0.2656)
# 李대표 (0.0000)
#
#
# Article 69 Top-10 keywords:
# 강북연세병원 (0.4026)
# 척추 (0.4026)
# 건강강좌 (0.4026)
# 20일 (0.3845)
# 건강한 (0.3225)
# 무료 (0.3156)
# 가족 (0.3020)
# 4월 (0.2665)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 70 Top-10 keywords:
# 듯한 (0.2933)
# 특허기술 (0.2933)
# 편안함 (0.2933)
# 조절해 (0.2933)
# 464개 (0.2933)
# 맞춘 (0.2933)
# 등받이 (0.2933)
# 소파 (0.2933)
# 다리 (0.2801)
# 선물 (0.2707)
#
#
# Article 71 Top-10 keywords:
# 억제에 (0.3227)
# 홍삼오일 (0.3227)
# 효소 (0.3227)
# 비대 (0.3227)
# 전립샘 (0.3227)
# 호르몬 (0.3227)
# 유발 (0.2978)
# 입증 (0.2899)
# 효과 (0.2778)
# 건강한 (0.2585)
#
#
# Article 72 Top-10 keywords:
# 침향환 (0.4203)
# 황금비율로 (0.4203)
# 증정 (0.3691)
# 건강한 (0.3367)
# 만든 (0.3233)
# 이벤트 (0.3205)
# 가족 (0.3153)
# 추가 (0.3006)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 73 Top-10 keywords:
# 종기 (0.3553)
# 겨드랑이 (0.3553)
# 사타구니 (0.3553)
# 한선염 (0.3553)
# 화농성 (0.3553)
# 반복 (0.3393)
# 의심 (0.3191)
# 건강한 (0.2846)
# 가족 (0.2665)
# 뒤로 (0.0000)
#
#
# Article 74 Top-10 keywords:
# 가냐 (0.3768)
# mz들 (0.3768)
# 퇴근하는데 (0.3768)
# 사장님 (0.3598)
# 3시 (0.3598)
# 벌써 (0.3478)
# 호소 (0.3139)
# 새벽 (0.3094)
# 김형기 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 75 Top-10 keywords:
# 야간진화 (0.4779)
# 작업 (0.4293)
# 투입 (0.3786)
# 드론 (0.3747)
# 인천 (0.3261)
# 마니산 (0.3177)
# 산불 (0.3104)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 76 Top-10 keywords:
# 제조법 (0.3780)
# 고추장 (0.3780)
# 된장 (0.3780)
# 걱정되면 (0.3780)
# 배우세요 (0.3780)
# 저염식 (0.3780)
# 소금 (0.3780)
# 들려온다 (0.0000)
# 들꽃 (0.0000)
# 뒤늦게 (0.0000)
#
#
# Article 77 Top-10 keywords:
# 시급한 (0.3823)
# 담보 (0.3823)
# 연체 (0.3651)
# 저축은행 (0.3651)
# 관리 (0.3357)
# 신용대출 (0.3235)
# 사상 (0.2940)
# 없는 (0.2633)
# 최고 (0.2608)
# 뒷동산 (0.0000)
#
#
# Article 78 Top-10 keywords:
# 이유들 (0.4371)
# 믿기 (0.4371)
# 대표의 (0.4035)
# 어려운 (0.4035)
# 말을 (0.3927)
# 민주당 (0.2754)
# 이재명 (0.2493)
# 뒤처진 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 79 Top-10 keywords:
# 9시간째 (0.4338)
# 대응체제로 (0.4338)
# 야간 (0.4004)
# 전환 (0.3401)
# 계속 (0.3122)
# 인천 (0.2960)
# 마니산 (0.2883)
# 산불 (0.2818)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 80 Top-10 keywords:
# 50분 (0.4039)
# 화성시 (0.4039)
# 산림청 (0.3904)
# 완료 (0.3474)
# 주불 (0.3253)
# 진화 (0.2974)
# 산불 (0.2747)
# 경기 (0.2682)
# 만에 (0.2427)
# 뒷말 (0.0000)
#
#
# Article 81 Top-10 keywords:
# 체험했습니다 (0.3194)
# 은혜 (0.3194)
# 선교사 (0.3194)
# 뮤어 (0.3194)
# 하나님 (0.3194)
# 안에서 (0.3194)
# 무엇이든 (0.3050)
# 것을 (0.2948)
# 우리는 (0.2869)
# 있다는 (0.2869)
#
#
# Article 82 Top-10 keywords:
# 동남부 (0.4242)
# 할퀸 (0.4242)
# 26명 (0.4051)
# 토네이도 (0.3652)
# 최소 (0.3439)
# 미국 (0.2775)
# 포토 (0.2765)
# 사망 (0.2664)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 83 Top-10 keywords:
# 발굴된 (0.3806)
# 2세 (0.3806)
# 2000여개 (0.3806)
# 람세스 (0.3679)
# 신전서 (0.3499)
# 머리 (0.3499)
# 미라 (0.3431)
# 포토 (0.2598)
# 뒷받침 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 84 Top-10 keywords:
# 50분만에 (0.4720)
# 야산서 (0.4720)
# 화성 (0.4720)
# 주불 (0.3631)
# 진화 (0.3319)
# 경기 (0.2993)
# 뚜렷 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤늦은 (0.0000)
# 뒤따라야 (0.0000)
#
#
# Article 85 Top-10 keywords:
# 끝낼 (0.3428)
# 보복공습 (0.3428)
# 점령 (0.3428)
# 영토 (0.3428)
# 비난 (0.3274)
# 미군 (0.3274)
# 이란 (0.3010)
# 시리아 (0.2951)
# 불법 (0.2661)
# 우리 (0.2592)
#
#
# Article 86 Top-10 keywords:
# 사진작가 (0.4475)
# 흐드러진 (0.4475)
# 윤중로 (0.4475)
# 벌써 (0.4131)
# 나도 (0.3787)
# 포토 (0.2917)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 87 Top-10 keywords:
# 기억하는 (0.7232)
# 노무현을 (0.6906)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 88 Top-10 keywords:
# 중국에 (0.4374)
# 환상을 (0.4374)
# 대통령은 (0.3929)
# 갖고 (0.3929)
# 온두라스 (0.3592)
# 대해 (0.3364)
# 있다 (0.2577)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 89 Top-10 keywords:
# 아침의 (0.7071)
# 문장 (0.7071)
# 李대표 (0.0000)
# 뒤따라야 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 90 Top-10 keywords:
# 싹텄다 (0.5125)
# 터전에서 (0.5125)
# 마야문명은 (0.5125)
# 종말의 (0.4604)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 91 Top-10 keywords:
# 식량 (0.7232)
# 안보 (0.6906)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 92 Top-10 keywords:
# 공중의 (0.4813)
# 하이라인 (0.4813)
# 생명 (0.4443)
# 나무 (0.4324)
# 도시 (0.3902)
# 드라마화 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 93 Top-10 keywords:
# 삼성 (1.0000)
# 李대표 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 94 Top-10 keywords:
# 정치학 (0.5154)
# 성묘 (0.5154)
# 중국과 (0.4922)
# 대만의 (0.4758)
# 뒤늦은 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 95 Top-10 keywords:
# 불투명 (0.3593)
# 가능해도 (0.3593)
# 대표주자 (0.3593)
# 야당 (0.3432)
# 출마 (0.3432)
# 미국도 (0.3317)
# 본선 (0.3155)
# 차기 (0.3040)
# 기소 (0.2740)
# 뒷불 (0.0000)
#
#
# Article 96 Top-10 keywords:
# 절연에 (0.3780)
# 과의 (0.3780)
# 달려 (0.3780)
# 박지현 (0.3610)
# 운명 (0.3490)
# 아니라 (0.3490)
# 개딸 (0.2935)
# 사퇴 (0.2545)
# 이재명 (0.2156)
# 뒤로 (0.0000)
#
#
# Article 97 Top-10 keywords:
# 않는다 (0.4134)
# 추격자는 (0.4134)
# 허상 (0.4134)
# 혁신기술은 (0.4134)
# 경쟁하지 (0.4134)
# 빠른 (0.3816)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 98 Top-10 keywords:
# 메이드인 (0.6133)
# gpt (0.5661)
# 코리아 (0.5509)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 99 Top-10 keywords:
# 폐기조치 (0.3968)
# 주키니 (0.3663)
# 유전자 (0.3484)
# 변형 (0.3484)
# 호박 (0.3484)
# 미승인 (0.3484)
# 수거 (0.3416)
# 유통 (0.3259)
# 뒷받침했다 (0.0000)
# 뒤따라야 (0.0000)
#
#
# Article 100 Top-10 keywords:
# 태어난 (0.4305)
# 저커버그 (0.4112)
# 태어나보니 (0.4112)
# 억만장자 (0.4112)
# 셋째 (0.3974)
# 아빠가 (0.3867)
# 듀엣곡 (0.0000)
# 드디어 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 101 Top-10 keywords:
# 우주선이다 (0.7071)
# 우주복은 (0.7071)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 102 Top-10 keywords:
# 드론이 (0.3962)
# 민간시설 (0.3962)
# 3명 (0.3572)
# 마을 (0.3572)
# 공격 (0.3408)
# 매체 (0.3408)
# 부상 (0.3163)
# 우크라 (0.3137)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 103 Top-10 keywords:
# 번아웃 (0.5310)
# 증후군 (0.5310)
# 2030 (0.4902)
# 빠진 (0.4424)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 104 Top-10 keywords:
# 외교의 (0.4791)
# 출발점 (0.4791)
# 협력은 (0.4791)
# 대일 (0.4575)
# 글로벌 (0.3197)
# 드라이브온 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 105 Top-10 keywords:
# 작가들의 (0.7439)
# 죽음 (0.6683)
# 李대표 (0.0000)
# 뒤처진 (0.0000)
# 뒤늦은 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 106 Top-10 keywords:
# 0시 (0.4069)
# 산림청 (0.3755)
# 강화도 (0.3572)
# 진화율 (0.3442)
# 79 (0.3442)
# 기준 (0.3299)
# 인천 (0.2776)
# 마니산 (0.2704)
# 산불 (0.2643)
# 뒷말 (0.0000)
#
#
# Article 107 Top-10 keywords:
# 도래 (0.6249)
# 나의 (0.6040)
# 시대 (0.4947)
# 李대표 (0.0000)
# 뒤로 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 108 Top-10 keywords:
# 닷새간 (0.4435)
# 재외공관장회의 (0.3894)
# 오늘부터 (0.3818)
# 외교부 (0.3818)
# 세일즈 (0.3694)
# 외교 (0.3411)
# 논의 (0.3277)
# 뒷받침 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 109 Top-10 keywords:
# 격돌 (0.4003)
# 전망 (0.3833)
# 법사위 (0.3511)
# 헌재 (0.3435)
# 결정 (0.3384)
# 오늘 (0.3384)
# 출석 (0.3173)
# 한동훈 (0.2726)
# 27일 (0.2182)
# 듀피젠트 (0.0000)
#
#
# Article 110 Top-10 keywords:
# 인질 (0.3763)
# 삼은 (0.3763)
# 안보리 (0.3510)
# 소집 (0.3510)
# 핵배치 (0.3510)
# 벨라루스 (0.3136)
# 우크라 (0.3083)
# 촉구 (0.2883)
# 종합 (0.2658)
# 뒷동산서 (0.0000)
#
#
# Article 111 Top-10 keywords:
# 노산이라 (0.3830)
# 둘째는 (0.3830)
# 첫째아 (0.3535)
# 키울 (0.3535)
# 낳아 (0.3440)
# 비중 (0.3297)
# 62 (0.3297)
# 없어 (0.2567)
# 최대 (0.2349)
# 李대표 (0.0000)
#
#
# Article 112 Top-10 keywords:
# 1쌍 (0.3192)
# 난임휴가는 (0.3192)
# 3쌍 (0.3192)
# 못꿔 (0.3192)
# 퇴사 (0.3192)
# 지원금 (0.3192)
# 난임부부 (0.3192)
# 꿈도 (0.3192)
# 0원 (0.3049)
# 40 (0.2342)
#
#
# Article 113 Top-10 keywords:
# 가게마다 (0.4281)
# 이랏샤이마세 (0.4281)
# 명동의 (0.4281)
# 44배 (0.4281)
# 돌아온 (0.3685)
# 매출 (0.3622)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 114 Top-10 keywords:
# 노마스크에 (0.3925)
# 헤어롤 (0.3925)
# 꾸꾸족 (0.3925)
# 립스틱 (0.3925)
# 바르고 (0.3749)
# 늘었다 (0.3526)
# 말고 (0.3447)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 115 Top-10 keywords:
# 모든 (0.4839)
# 주변엔 (0.3145)
# 없나요 (0.3145)
# 저출생 (0.3145)
# 것의 (0.3145)
# 인구가 (0.3145)
# 것이다 (0.3004)
# 혜택 (0.2903)
# 대책 (0.2466)
# 단독 (0.1894)
#
#
# Article 116 Top-10 keywords:
# 온난화에 (0.4472)
# 꽁치 (0.4472)
# 金치 (0.4472)
# 한중일 (0.4472)
# 밥상서 (0.4472)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 117 Top-10 keywords:
# 獨처럼 (0.3615)
# 12일씩 (0.3615)
# 보상은 (0.3615)
# 없애야 (0.3615)
# 휴가 (0.3615)
# 포커스 (0.3615)
# 금전 (0.3452)
# 이슈 (0.3112)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 118 Top-10 keywords:
# 오라 (0.5385)
# 중앙지방협력회의 (0.5385)
# 모든 (0.4142)
# 장관 (0.3786)
# 단독 (0.3243)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 119 Top-10 keywords:
# 탄도 (0.3503)
# 타격감 (0.3503)
# 번도 (0.3503)
# 로마로 (0.3503)
# 아이언 (0.3345)
# 경험 (0.3234)
# 못한 (0.3147)
# 비거리 (0.3147)
# 잡은 (0.3076)
# 뒤쪽의 (0.0000)
#
#
# Article 120 Top-10 keywords:
# 테일러메이드 (0.4621)
# 스텔스2 (0.4621)
# 빗맞아도 (0.4621)
# 스피드 (0.4413)
# 유지 (0.4057)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 121 Top-10 keywords:
# 가볍지만 (0.4336)
# 레이디 (0.4336)
# 마스터스 (0.4141)
# 멀리 (0.4141)
# 뜬다 (0.4003)
# 클럽 (0.3474)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 122 Top-10 keywords:
# 매니저 (0.3780)
# 유현주 (0.3780)
# 변기수가 (0.3780)
# g멤버십 (0.3780)
# 코스 (0.3780)
# 스마트한 (0.3780)
# 골프존 (0.3780)
# 듀엣곡 (0.0000)
# 뒤쪽의 (0.0000)
# 드라마로 (0.0000)
#
#
# Article 123 Top-10 keywords:
# 젝시오볼 (0.3765)
# 입점 (0.3765)
# 한정판 (0.3765)
# 선물하기 (0.3765)
# 카톡 (0.3595)
# 극대화 (0.3595)
# 비거리 (0.3382)
# 국내 (0.2454)
# 뒤쪽의 (0.0000)
# 뒤따라야 (0.0000)
#
#
# Article 124 Top-10 keywords:
# 섀시 (0.3638)
# 캘러웨이 (0.3638)
# 평정 (0.3638)
# 카본 (0.3474)
# 360도 (0.3474)
# 패러다임 (0.3358)
# 업계 (0.2949)
# pga (0.2914)
# 최초 (0.2774)
# 뒷말 (0.0000)
#
#
# Article 125 Top-10 keywords:
# 떠났어도 (0.3935)
# 여민수 (0.3935)
# 357억 (0.3935)
# 331억 (0.3935)
# 연봉킹 (0.3935)
# 조수용 (0.3758)
# 카카오 (0.2908)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 126 Top-10 keywords:
# 치킨값 (0.5418)
# 3만원 (0.5237)
# 배달 (0.4982)
# 시대 (0.4290)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 127 Top-10 keywords:
# 36m (0.3551)
# 항해 (0.3551)
# k조선 (0.3551)
# 꼭대기서 (0.3551)
# lng (0.3551)
# 초격차 (0.3391)
# 한눈에 (0.3278)
# 기술 (0.2845)
# 미래 (0.2571)
# 둘레길서 (0.0000)
#
#
# Article 128 Top-10 keywords:
# 가계대출 (0.3785)
# 인하 (0.3614)
# 응답 (0.3614)
# 이복현 (0.3614)
# 방문에 (0.3614)
# 상생금융 (0.3493)
# 신한은행 (0.3400)
# 금리 (0.3108)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 129 Top-10 keywords:
# 회장님 (0.4194)
# 금융지주 (0.4194)
# 능력 (0.3871)
# 입증 (0.3767)
# 바뀐 (0.3767)
# 시동 (0.3444)
# 경영 (0.3099)
# 뒷불 (0.0000)
# 듀엣곡 (0.0000)
# 뒷받침했다 (0.0000)
#
#
# Article 130 Top-10 keywords:
# gm (0.4482)
# 공급사 (0.4482)
# 포스코퓨처엠 (0.4263)
# 최우수 (0.4180)
# lg전자 (0.3588)
# 선정 (0.3361)
# 뒷받침 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 131 Top-10 keywords:
# 미시시피주 (0.4400)
# 강타 (0.4202)
# 선포 (0.4062)
# 바이든 (0.4062)
# 비상사태 (0.3953)
# 토네이도 (0.3788)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 132 Top-10 keywords:
# 하나의 (0.4057)
# 中과 (0.3745)
# 대만과 (0.3745)
# 수교 (0.3562)
# 단교 (0.3562)
# 인정 (0.3380)
# 온두라스 (0.3332)
# 중국 (0.2755)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 133 Top-10 keywords:
# 미중 (0.3770)
# 돌파구 (0.3644)
# 찾는 (0.3546)
# 행보 (0.3466)
# 갈등 (0.3200)
# 이재용 (0.3010)
# 찾은 (0.2961)
# 3년 (0.2791)
# 글로벌 (0.2635)
# 만에 (0.2265)
#
#
# Article 134 Top-10 keywords:
# 장석훈의 (0.4157)
# 성공할까 (0.4157)
# 실적난 (0.4157)
# 삼성증권 (0.3970)
# 주가 (0.3650)
# 하락세 (0.3650)
# 반전 (0.2400)
# 듀엣곡 (0.0000)
# 뒷불 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 135 Top-10 keywords:
# 하이브는 (0.4139)
# 오버부킹 (0.4139)
# 손실 (0.3952)
# 수백억 (0.3718)
# 카카오 (0.3058)
# 공개매수 (0.2997)
# sm (0.2997)
# 가능성 (0.2997)
# 둘러보고 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 136 Top-10 keywords:
# 위협 (0.4006)
# 코앞 (0.4006)
# 나토 (0.3937)
# 전술핵 (0.3686)
# 벨라루스에 (0.3686)
# 푸틴 (0.3612)
# 배치 (0.3490)
# 듣자마자 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤늦게 (0.0000)
#
#
# Article 137 Top-10 keywords:
# 양극재 (0.4197)
# 음극재 (0.4197)
# 받을까 (0.4197)
# 美서 (0.4008)
# 한국산 (0.4008)
# 세액공제 (0.3874)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 138 Top-10 keywords:
# 내연기관 (0.4089)
# eu (0.4089)
# 2035년부터 (0.4089)
# 합의 (0.3774)
# 퇴출 (0.3520)
# 차량 (0.3406)
# 독일 (0.3406)
# 李대표 (0.0000)
# 뒷받침 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 139 Top-10 keywords:
# 메운 (0.3620)
# 2000여명 (0.3457)
# 품새 (0.3341)
# 기네스 (0.3341)
# 광화문 (0.3252)
# 물결 (0.3178)
# 경신 (0.3178)
# 1만 (0.3063)
# 세계 (0.2532)
# 기록 (0.2458)
#
#
# Article 140 Top-10 keywords:
# 늘려 (0.3689)
# 부양 (0.3689)
# 세일 (0.3689)
# 할인쿠폰 (0.3523)
# 숙박 (0.3406)
# 소비 (0.3314)
# 대규모 (0.3239)
# 나선다 (0.2864)
# 경기 (0.2339)
# 李대표 (0.0000)
#
#
# Article 141 Top-10 keywords:
# 46용사 (0.5189)
# 천안함 (0.5016)
# 13주기 (0.5016)
# 추모식 (0.4771)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 142 Top-10 keywords:
# 경기남부청장 (0.4384)
# 발탁 (0.4229)
# 내부 (0.4106)
# 내정 (0.4070)
# 국수본부장 (0.4070)
# 우종수 (0.3593)
# 드디어 (0.0000)
# 듀피젠트 (0.0000)
# 듀엣곡 (0.0000)
# 뒷불 (0.0000)
#
#
# Article 143 Top-10 keywords:
# 추모공간 (0.4098)
# 기소유예 (0.3914)
# 고려 (0.3783)
# 상인 (0.3783)
# 훼손 (0.3681)
# 상생 (0.3467)
# 이태원 (0.2758)
# 단독 (0.2468)
# 둘러보고 (0.0000)
# 둘러보니 (0.0000)
#
#
# Article 144 Top-10 keywords:
# 확보戰 (0.4381)
# 신병 (0.4184)
# 싱가포르와 (0.4184)
# 송환 (0.4044)
# 권도형 (0.3286)
# 넘어 (0.3238)
# 국내 (0.2856)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 145 Top-10 keywords:
# 사과부터 (0.4186)
# 복당부터 (0.4186)
# 내홍 (0.4046)
# 행보 (0.3848)
# 민형배 (0.3773)
# 다시 (0.3135)
# 민주 (0.3117)
# 李대표 (0.0000)
# 뒷받침 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 146 Top-10 keywords:
# 방치한 (0.4095)
# 공기뿐이었다 (0.4095)
# 곁엔 (0.4095)
# 544시간 (0.4095)
# 엄마 (0.3780)
# 숨진 (0.3320)
# 아들 (0.2757)
# 李대표 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 147 Top-10 keywords:
# 후폭풍 (0.4257)
# 검수완박법 (0.3842)
# 격돌 (0.3842)
# 두고 (0.3754)
# 이번엔 (0.3645)
# 검수원복 (0.3613)
# 시행령 (0.3454)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 148 Top-10 keywords:
# 花한 (0.4472)
# 웃음꽃도 (0.4472)
# 설렘 (0.4472)
# 꽃길따라 (0.4472)
# 피어납니다 (0.4472)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 149 Top-10 keywords:
# 재점화 (0.4419)
# 뇌관 (0.4301)
# 퇴진론 (0.4051)
# 사무총장 (0.3717)
# 교체 (0.3564)
# 민주 (0.3404)
# 이재명 (0.2730)
# 듀피젠트 (0.0000)
# 뒷동산 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 150 Top-10 keywords:
# 사드 (0.3737)
# 기지 (0.3569)
# 수렴 (0.3569)
# 7월 (0.3449)
# 정상화 (0.3281)
# 이르면 (0.3217)
# 마무리 (0.3162)
# 이달 (0.3113)
# 의견 (0.2803)
# 李대표 (0.0000)
#
#
# Article 151 Top-10 keywords:
# 우상화하는 (0.4432)
# 5시에 (0.4432)
# 불면증까지 (0.4432)
# 김정은 (0.3816)
# 하루 (0.3640)
# 새벽 (0.3640)
# 둘러보고 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 152 Top-10 keywords:
# 터졌는데 (0.3762)
# 헛도는 (0.3762)
# 대응책이 (0.3762)
# 제재 (0.3592)
# 국제사회 (0.3592)
# 북핵 (0.3592)
# 핵어뢰 (0.3183)
# 없다 (0.2949)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 153 Top-10 keywords:
# 결포족 (0.3506)
# 속출 (0.3506)
# 투톱 (0.3506)
# 中베이징도 (0.3506)
# 양육비 (0.3506)
# 19년 (0.3150)
# 출생아 (0.2967)
# 이어 (0.2539)
# 사망 (0.2202)
# 단독 (0.2111)
#
#
# Article 154 Top-10 keywords:
# 부처별 (0.3608)
# 쏟고도 (0.3608)
# 따로 (0.3608)
# 280조 (0.3445)
# 실패 (0.3330)
# 정책에 (0.3241)
# 효과 (0.3106)
# 저출산 (0.2963)
# 단독 (0.2172)
# 반전 (0.2083)
#
#
# Article 155 Top-10 keywords:
# 예타 (0.4005)
# 말이다 (0.4005)
# 군공항 (0.3824)
# 신공항 (0.3824)
# tk (0.3597)
# 면제 (0.3109)
# 사설 (0.3080)
# 광주 (0.2565)
# 두자릿수 (0.0000)
# 뒷받침 (0.0000)
#
#
# Article 156 Top-10 keywords:
# 팀은 (0.4700)
# 캡틴 (0.4700)
# 11번 (0.4700)
# no (0.4338)
# 역사 (0.3860)
# 드디어 (0.0000)
# 듀피젠트 (0.0000)
# 드라마화 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 157 Top-10 keywords:
# 한상혁 (0.3936)
# 길들이기 (0.3759)
# 드러낸 (0.3759)
# 실체 (0.3759)
# 文정부 (0.3535)
# 방송 (0.3278)
# 영장 (0.3118)
# 사설 (0.3027)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 158 Top-10 keywords:
# 꽃핀 (0.5147)
# 키즈 (0.4751)
# 연아 (0.4751)
# 10년 (0.4431)
# 만에 (0.2953)
# 들어달라 (0.0000)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 159 Top-10 keywords:
# 씨줄날줄 (0.4472)
# 박록삼 (0.4472)
# 논설위원 (0.4472)
# 백기 (0.4472)
# 누누tv (0.4472)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 160 Top-10 keywords:
# 진정 (0.4100)
# 내세울 (0.4100)
# 국익 (0.4100)
# 장외투쟁 (0.4100)
# 있나 (0.3469)
# 주말 (0.3284)
# 사설 (0.3153)
# 李대표 (0.0000)
# 뒤처진 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 161 Top-10 keywords:
# 봄이지 (0.4561)
# 황수정 (0.4561)
# 수석논설위원 (0.4561)
# 길섶에서 (0.4561)
# 이게 (0.4097)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 162 Top-10 keywords:
# 강대국 (0.6231)
# 김경민의 (0.3116)
# 명예교수 (0.3116)
# 이어야 (0.3116)
# 강대국이다 (0.3116)
# 한양대 (0.2975)
# 대한민국 (0.2636)
# 미사일 (0.2559)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 163 Top-10 keywords:
# 반도체지원법 (0.3308)
# out (0.3308)
# lt학부 (0.3308)
# 한국외대 (0.3308)
# 전략은 (0.3308)
# 강유덕 (0.3308)
# in (0.3160)
# 유럽 (0.2756)
# 교수 (0.2621)
# 대응 (0.2237)
#
#
# Article 164 Top-10 keywords:
# 정책연구소장 (0.2498)
# 해양법 (0.2498)
# 거점화해야 (0.2498)
# 암초로 (0.2498)
# 넓이 (0.2498)
# 한국해양과학기술원 (0.2498)
# 태평양 (0.2498)
# 新해양시대론 (0.2498)
# 양희철의 (0.2498)
# 코드 (0.2498)
#
#
# Article 165 Top-10 keywords:
# 대전환해야 (0.3278)
# 김성진의 (0.3278)
# 서치라이트 (0.3278)
# 소멸 (0.3278)
# 미래한국 (0.3278)
# 산업통상자원부 (0.3278)
# 패러다임 (0.3025)
# 대변인 (0.2878)
# 인구 (0.2626)
# 정책 (0.2405)
#
#
# Article 166 Top-10 keywords:
# 에디터 (0.3688)
# 신문국 (0.3688)
# 데스크 (0.3688)
# 영약삼단과 (0.3688)
# 이제훈 (0.3522)
# 시각 (0.3522)
# 동맹 (0.3522)
# 새로운 (0.2892)
# 李대표 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 167 Top-10 keywords:
# 쏠까 (0.5067)
# 데뷔전 (0.4677)
# 유해란 (0.4449)
# lpga (0.4362)
# 우승 (0.3693)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 168 Top-10 keywords:
# 튀지 (0.3466)
# prgr (0.3466)
# irons (0.3466)
# 쳐도 (0.3466)
# 절묘함 (0.3466)
# 쓸어 (0.3310)
# 기술력 (0.3310)
# the (0.3113)
# 않는 (0.2887)
# 들려주는 (0.0000)
#
#
# Article 169 Top-10 keywords:
# 화양 (0.3610)
# 쌍벽 (0.3610)
# 초품아 (0.3610)
# 눈앞 (0.3448)
# 평택 (0.3448)
# 뜬다 (0.3333)
# 코앞 (0.3108)
# 바다 (0.3055)
# 학교 (0.2649)
# 뒷받침했다 (0.0000)
#
#
# Article 170 Top-10 keywords:
# 동화에 (0.3981)
# 어른을 (0.3981)
# 화원에서 (0.3981)
# 빠지다 (0.3981)
# 꽃향기 (0.3981)
# 가득한 (0.3802)
# 위한 (0.2508)
# 드라마로 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 171 Top-10 keywords:
# 오늘의 (0.7463)
# 경기 (0.6656)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 172 Top-10 keywords:
# 구사일생 (0.4764)
# 멍군 (0.4764)
# 혈투 (0.4550)
# 희망의 (0.4550)
# 한전 (0.3632)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 173 Top-10 keywords:
# 차무식과 (0.4144)
# 시든 (0.4144)
# 권무십일홍 (0.4144)
# 결말이죠 (0.4144)
# 어울리는 (0.3957)
# 들꽃 (0.3957)
# 두었던 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 174 Top-10 keywords:
# 100만장 (0.4062)
# 페이스 (0.3879)
# bts (0.3566)
# 폭발 (0.3497)
# 지민 (0.3436)
# 솔로 (0.3436)
# 첫날 (0.3184)
# 인기 (0.3124)
# 뒷받침 (0.0000)
# 뒷받침했다 (0.0000)
#
#
# Article 175 Top-10 keywords:
# 지다 (0.4398)
# 거성 (0.4398)
# 美반도체 (0.4398)
# 무어의 (0.3951)
# 법칙 (0.3862)
# 만든 (0.3383)
# 듀피젠트 (0.0000)
# 뒤처진 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 176 Top-10 keywords:
# 인사 (1.0000)
# 뒷받침 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 177 Top-10 keywords:
# 19혁명 (0.4221)
# 윤식 (0.4221)
# 주도 (0.3896)
# 학생 (0.3706)
# 별세 (0.3516)
# 서울대 (0.3516)
# 의원 (0.3277)
# 뒷받침했다 (0.0000)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 178 Top-10 keywords:
# 금손들 (0.4611)
# 34명의 (0.4611)
# 금자탑 (0.4611)
# 7연패 (0.4256)
# 장애인기능올림픽 (0.4256)
# 두자릿수 (0.0000)
# 뒷받침했다 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 179 Top-10 keywords:
# dokdo (0.5951)
# 세계가 (0.5683)
# 배운다 (0.5683)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 180 Top-10 keywords:
# 측정기 (0.3935)
# 1초에 (0.3935)
# 스캔 (0.3935)
# 마이캐디 (0.3935)
# 버튼 (0.3758)
# 역대급 (0.3632)
# 하나로 (0.3278)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 181 Top-10 keywords:
# 은발의 (0.4165)
# 달라진 (0.4165)
# 대신에 (0.4165)
# 시내로 (0.4165)
# 시골 (0.3978)
# 청춘 (0.3845)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 182 Top-10 keywords:
# 우여곡절 (0.5000)
# 날개 (0.4615)
# 이스타항공 (0.4492)
# 다시 (0.3576)
# 3년 (0.3535)
# 만에 (0.2869)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 183 Top-10 keywords:
# 자부심 (0.4303)
# 야마하 (0.4303)
# 드라이브 (0.4109)
# 아이언 (0.4109)
# 비거리 (0.3865)
# 스타 (0.3778)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 184 Top-10 keywords:
# 홀리는 (0.3688)
# 한계 (0.3688)
# 골프웨어 (0.3688)
# 골든베어 (0.3688)
# 패턴도 (0.3688)
# 색도 (0.3688)
# mz세대 (0.3313)
# 넘어 (0.2725)
# 듀엣곡 (0.0000)
# 뒷불 (0.0000)
#
#
# Article 185 Top-10 keywords:
# 브리지스톤 (0.3932)
# 아마추어 (0.3932)
# 콘택트 (0.3932)
# 탑재 (0.3755)
# 신형 (0.3629)
# 맞춤 (0.3629)
# 신기술 (0.3629)
# 둘러봤다 (0.0000)
# 뒤에도 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 186 Top-10 keywords:
# 우아하게 (0.3638)
# 일상서도 (0.3638)
# 엘로드 (0.3638)
# 필드서도 (0.3638)
# 3040 (0.3638)
# 취향 (0.3358)
# 스타일 (0.3358)
# 저격 (0.3358)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 187 Top-10 keywords:
# 정여울의 (0.3265)
# 달래주네 (0.3265)
# 잔잔하게 (0.3265)
# 스페이스 (0.3265)
# 평온 (0.3265)
# 지친마음 (0.3265)
# 힐링 (0.3119)
# 평화 (0.3014)
# 안정 (0.2933)
# 휴식 (0.2933)
#
#
# Article 188 Top-10 keywords:
# 日제약회사 (0.4049)
# 무슨일 (0.4049)
# 中서 (0.3913)
# 스파이 (0.3913)
# 직원 (0.3437)
# 가능성 (0.3070)
# 구속 (0.3032)
# 혐의 (0.2480)
# 동아쏘시오그룹이 (0.0000)
# 뒷불 (0.0000)
#
#
# Article 189 Top-10 keywords:
# 김동완의 (0.5451)
# 운세 (0.4786)
# 오늘의 (0.3876)
# 2023년 (0.3833)
# 3월 (0.3445)
# 27일 (0.2409)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 190 Top-10 keywords:
# 드론이 (0.4234)
# 민간시설 (0.4234)
# 3명 (0.3817)
# 공격 (0.3641)
# 매체 (0.3641)
# 우크라이나 (0.3410)
# 부상 (0.3380)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 191 Top-10 keywords:
# 군사훈련 (0.3673)
# 사회복무요원도 (0.3673)
# 집총 (0.3673)
# 종교 (0.3507)
# 처벌해야 (0.3507)
# 이유로 (0.3299)
# 거부 (0.3059)
# 대법 (0.2879)
# 없는 (0.2530)
# 뒤에서 (0.0000)
#
#
# Article 192 Top-10 keywords:
# 변화없어 (0.4068)
# 핵태세 (0.3885)
# 핵위협 (0.3654)
# 불필요 (0.3654)
# 무책임 (0.3502)
# 나토 (0.3442)
# 위험 (0.3158)
# 대응 (0.2750)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 193 Top-10 keywords:
# 보여줬다가 (0.4240)
# 초등생에 (0.4240)
# 다비드상 (0.3914)
# 美교장 (0.3914)
# 당한 (0.3651)
# 해임 (0.3262)
# 이유는 (0.3071)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 194 Top-10 keywords:
# 갚을 (0.3985)
# 수천억 (0.3985)
# 대만서 (0.3985)
# 빌린 (0.3985)
# 먹튀 (0.3678)
# 단교 (0.3499)
# 온두라스 (0.3273)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 드라마 (0.0000)
#
#
# Article 195 Top-10 keywords:
# 내는 (0.3702)
# 재산 (0.3702)
# 많죠 (0.3702)
# 김구라가 (0.3702)
# 얼마길래 (0.3535)
# 건보료 (0.3325)
# 세무사 (0.3325)
# 깜짝 (0.3250)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 196 Top-10 keywords:
# 알림 (0.7071)
# 3월27일 (0.7071)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 197 Top-10 keywords:
# 벨라루스로 (0.4639)
# 옮겼다는 (0.4515)
# 징후 (0.4187)
# 아직 (0.3902)
# 핵무기 (0.3741)
# 없어 (0.3369)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 198 Top-10 keywords:
# 뇌진탕 (0.4246)
# 퇴원 (0.4246)
# 공화 (0.4246)
# 낙상으로 (0.4246)
# 원내대표 (0.3920)
# 상원 (0.3537)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 199 Top-10 keywords:
# 원해 (0.4136)
# 키워주는 (0.4136)
# 키울수 (0.4136)
# 세상보다 (0.3950)
# 세상 (0.3715)
# 내가 (0.3353)
# 있는 (0.2835)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 200 Top-10 keywords:
# 7번 (0.4081)
# 클린점프로 (0.4081)
# 세계선수권도 (0.4081)
# 개척해온 (0.4081)
# 메달 (0.3767)
# 최초 (0.3111)
# 차준환 (0.3085)
# 들썩일 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 201 Top-10 keywords:
# 생존 (0.3525)
# 헌신영예기장 (0.3525)
# 58명에 (0.3525)
# 46용사 (0.3367)
# 천안함 (0.3254)
# 13주기 (0.3254)
# 장병 (0.3254)
# 해군 (0.3167)
# 추모식 (0.3095)
# 뒤따라야 (0.0000)
#
#
# Article 202 Top-10 keywords:
# 정상회담때 (0.4545)
# 공동문안 (0.4195)
# 핵우산 (0.4083)
# 한미 (0.3496)
# 내달 (0.3115)
# 추진 (0.2837)
# 강화 (0.2758)
# 단독 (0.2737)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 203 Top-10 keywords:
# 은행위기 (0.5092)
# 도이체방크 (0.4471)
# 급락 (0.4128)
# 이번엔 (0.3916)
# 14 (0.3398)
# 장중 (0.3188)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 204 Top-10 keywords:
# 힘든 (0.3597)
# 둘째 (0.3320)
# 보기 (0.3320)
# 첫째 (0.3320)
# 63 (0.3231)
# 비중 (0.3097)
# 출생아 (0.3043)
# 작년 (0.2639)
# 역대 (0.2558)
# 최고 (0.2454)
#
#
# Article 205 Top-10 keywords:
# 음울함 (0.4680)
# 화려함 (0.4680)
# 신진 (0.4470)
# 브라질 (0.4470)
# 작가의 (0.4029)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 206 Top-10 keywords:
# 냉소 (0.3823)
# 없앨 (0.3823)
# 5년내 (0.3823)
# 2030의 (0.3823)
# 찾아야 (0.3651)
# 방안 (0.3235)
# 저출산 (0.3140)
# 정책 (0.2806)
# 李대표 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 207 Top-10 keywords:
# 춤춘다 (0.4204)
# 객석 (0.4204)
# 관객들이 (0.4204)
# 허물자 (0.4204)
# 무대 (0.3880)
# 경계 (0.3776)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 208 Top-10 keywords:
# 불교문화 (0.4882)
# 서울국제불교박람회 (0.4882)
# 소개 (0.4882)
# 30일 (0.3827)
# 개막 (0.3722)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 209 Top-10 keywords:
# 상실감 (0.4082)
# 수치심 (0.4082)
# 연원을 (0.4082)
# 어른되어 (0.4082)
# 찾아서 (0.4082)
# 느끼는 (0.4082)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 210 Top-10 keywords:
# 맥주로 (0.4472)
# 멕시코서 (0.4472)
# 타코와 (0.4472)
# 버텨 (0.4472)
# 조각땐 (0.4472)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 211 Top-10 keywords:
# 日은 (0.4040)
# 핵무장 (0.4040)
# 된다는데 (0.4040)
# 6개월이면 (0.4040)
# 발언 (0.3236)
# 주목 (0.3107)
# 관련 (0.2945)
# 단독 (0.2433)
# 뒷동산 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 212 Top-10 keywords:
# 나토를 (0.3832)
# 위협하려는 (0.3832)
# 배치하기로 (0.3660)
# 푸틴의 (0.3538)
# 서방 (0.3107)
# 벨라루스에 (0.3036)
# 게임 (0.2975)
# 푸틴 (0.2975)
# 핵무기 (0.2853)
# 뒤에도 (0.0000)
#
#
# Article 213 Top-10 keywords:
# 100kg (0.3947)
# 김성란씨 (0.3947)
# 묵호항서 (0.3947)
# 문어 (0.3947)
# 삶는 (0.3947)
# 채널a (0.3770)
# 오늘의 (0.2807)
# 드라마 (0.0000)
# 드디어 (0.0000)
# 두산은 (0.0000)
#
#
# Article 214 Top-10 keywords:
# 인하할 (0.3262)
# 건들락은 (0.3262)
# 채권왕 (0.3262)
# 美금리 (0.3262)
# 매파 (0.3115)
# 연준 (0.3115)
# 시사 (0.2930)
# 대폭 (0.2864)
# 75 (0.2717)
# 금리 (0.2679)
#
#
# Article 215 Top-10 keywords:
# 운세 (0.6419)
# 오늘의 (0.5198)
# 3월 (0.4620)
# 27일 (0.3230)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 216 Top-10 keywords:
# 신화 (0.4293)
# 격파 (0.4293)
# 모로코 (0.4293)
# 브라질 (0.4100)
# 4강 (0.4100)
# 월드컵 (0.3332)
# 李대표 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 217 Top-10 keywords:
# 비은행권 (0.4677)
# 115조 (0.4677)
# 위험노출액 (0.4467)
# 부동산pf (0.4317)
# 사상최대 (0.4202)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 218 Top-10 keywords:
# 31득점 (0.3732)
# 11도움 (0.3732)
# 요키치 (0.3732)
# 서부 (0.3732)
# 웃었다 (0.3732)
# 덴버 (0.3564)
# 대결 (0.3352)
# 1위 (0.2534)
# 둘러보니 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 219 Top-10 keywords:
# 벼랑끝 (0.3984)
# 23점 (0.3984)
# 구했다 (0.3984)
# po경기 (0.3984)
# 임성진 (0.3805)
# 창단 (0.3579)
# 한전 (0.3037)
# 李대표 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 220 Top-10 keywords:
# 원내대표까지 (0.4327)
# 구도 (0.4327)
# 윤재옥 (0.4132)
# 김학용 (0.3994)
# 대결 (0.3887)
# 친윤 (0.3799)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 221 Top-10 keywords:
# 손절 (0.3821)
# 변했다며 (0.3821)
# 내게도 (0.3821)
# 개딸들 (0.3821)
# 안되는 (0.3649)
# 전화 (0.3432)
# 통제 (0.3432)
# 이재명 (0.2179)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 222 Top-10 keywords:
# 프리롤 (0.4153)
# 춤추게 (0.4153)
# 앞으로도 (0.4153)
# 손흥민 (0.3647)
# 같은 (0.3460)
# 클린스만 (0.3411)
# 역할 (0.3367)
# 드디어 (0.0000)
# 뒤쪽의 (0.0000)
# 드라마로 (0.0000)
#
#
# Article 223 Top-10 keywords:
# 36건중 (0.3539)
# 부패사건 (0.3539)
# 체포안 (0.3539)
# 3건뿐 (0.3539)
# 25건 (0.3539)
# 가결 (0.3539)
# 유죄 (0.3380)
# 의원 (0.2747)
# 국회 (0.2426)
# 뒤에서 (0.0000)
#
#
# Article 224 Top-10 keywords:
# 계속된다 (0.4195)
# 잔치는 (0.4195)
# 타점왕 (0.4195)
# 마흔 (0.4195)
# 향해 (0.4006)
# 통산 (0.3683)
# 듀엣곡 (0.0000)
# 뒷불 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 225 Top-10 keywords:
# 광화문광장서 (0.3888)
# 세계新 (0.3888)
# 태권도인 (0.3888)
# 단체시연 (0.3888)
# 1만2263명 (0.3713)
# 기네스 (0.3589)
# 품새 (0.3589)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 226 Top-10 keywords:
# 경남신문 (0.4810)
# 정기홍 (0.4810)
# 편집국장 (0.4810)
# 별세 (0.4007)
# 부고 (0.3811)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 227 Top-10 keywords:
# 한겨레신문사 (0.8081)
# 인사 (0.5890)
# 뒷면에는 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 228 Top-10 keywords:
# 조절을 (0.4002)
# 하라리 (0.3822)
# 인류 (0.3822)
# 장악 (0.3694)
# ai가 (0.3386)
# 못하게 (0.3245)
# 도입 (0.3107)
# 속도 (0.3078)
# 듀엣곡 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 229 Top-10 keywords:
# 안중근의사 (0.5274)
# 순국 (0.5037)
# 113주기 (0.5037)
# 추모식 (0.4631)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 230 Top-10 keywords:
# 평신도 (0.4148)
# 지도자까지 (0.4148)
# 성학대 (0.4148)
# 교황 (0.3961)
# 의무화 (0.3829)
# 신고 (0.3190)
# 확대 (0.2804)
# 뒤쪽의 (0.0000)
# 뒤늦은 (0.0000)
# 뒤따라야 (0.0000)
#
#
# Article 231 Top-10 keywords:
# 공동창립 (0.4149)
# 이르면 (0.4149)
# 영장 (0.3818)
# 재청구 (0.3675)
# 신현성 (0.3675)
# 테라 (0.3615)
# 오늘 (0.3304)
# 듀엣곡 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 232 Top-10 keywords:
# 18개로 (0.6081)
# 장애인기능올림픽 (0.5613)
# 7연패 (0.5613)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 233 Top-10 keywords:
# 항소할 (0.3199)
# 국내송환 (0.3199)
# 권측 (0.3199)
# 상당시일 (0.3199)
# 걸릴듯 (0.3199)
# 최장 (0.3055)
# 구금 (0.2952)
# 몬테네그로 (0.2952)
# 30일 (0.2508)
# 권도형 (0.2399)
#
#
# Article 234 Top-10 keywords:
# 무어의 (0.4348)
# 전설 (0.4250)
# 법칙 (0.4250)
# 남기고 (0.4167)
# 떠난 (0.4032)
# 반도체 (0.3368)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 235 Top-10 keywords:
# 되도록 (0.3705)
# 입법공백 (0.3705)
# 코인 (0.3538)
# 투자자 (0.3420)
# 여전 (0.3253)
# 사태 (0.3253)
# 보호 (0.3190)
# 1년 (0.3043)
# 테라 (0.2779)
# 뒤쪽의 (0.0000)
#
#
# Article 236 Top-10 keywords:
# 평균연봉 (0.4464)
# sk스퀘어 (0.4464)
# 3곳 (0.4263)
# 2억 (0.3919)
# 대기업 (0.3718)
# 나왔다 (0.3576)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 237 Top-10 keywords:
# 민생과 (0.4182)
# 산업의 (0.4182)
# 한화진 (0.4182)
# 물그릇 (0.4182)
# 키우기 (0.3993)
# 기고 (0.3756)
# 뒷불 (0.0000)
# 뒷받침했다 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 238 Top-10 keywords:
# 6년간 (0.4173)
# 넉달새 (0.4173)
# 문잠근 (0.4173)
# 12종 (0.4173)
# 韓게임에 (0.4173)
# 허가 (0.3593)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 239 Top-10 keywords:
# 교육 (0.5701)
# 공부를 (0.3558)
# 신종호 (0.3558)
# 공부하다 (0.3558)
# 아닌 (0.2964)
# 시대 (0.2690)
# 해야 (0.2690)
# ai (0.2502)
# 뒷불 (0.0000)
# 뒷받침했다 (0.0000)
#
#
# Article 240 Top-10 keywords:
# 단절 (0.4014)
# 모아놓고 (0.4014)
# 공급망 (0.3833)
# 100명 (0.3705)
# 안돼 (0.3456)
# 공격 (0.3297)
# ceo (0.3060)
# 글로벌 (0.2679)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 241 Top-10 keywords:
# 보물 (0.4818)
# 강화도 (0.4709)
# 위협 (0.4617)
# 국가 (0.4538)
# 마니산 (0.3565)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 242 Top-10 keywords:
# 푸니타 (0.3763)
# 바자즈 (0.3763)
# 이해하는 (0.3763)
# 名문장 (0.3763)
# 것이 (0.3593)
# 이기는 (0.3473)
# 내가 (0.3051)
# 만난 (0.3014)
# 뒷불 (0.0000)
# 드디어 (0.0000)
#
#
# Article 243 Top-10 keywords:
# 방치돼 (0.3742)
# 한공기뿐 (0.3742)
# 옆엔 (0.3742)
# 사흘간 (0.3574)
# 엄마는 (0.3574)
# 외박 (0.3454)
# 아기 (0.3362)
# 숨진 (0.3034)
# 듀엣곡 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 244 Top-10 keywords:
# 카자흐인 (0.4373)
# 불허 (0.4373)
# 인천공항서 (0.4191)
# 입국 (0.3998)
# 도주 (0.3856)
# 2명 (0.3651)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 245 Top-10 keywords:
# 바람개비 (0.7071)
# 상족암 (0.7071)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 246 Top-10 keywords:
# 경기남부청장 (0.5373)
# 국수본부장에 (0.5183)
# 내정 (0.4988)
# 우종수 (0.4404)
# 드라마화 (0.0000)
# 드라마로 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 247 Top-10 keywords:
# 솟아라 (0.5860)
# 솟대야 (0.5860)
# 고양이 (0.5596)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 248 Top-10 keywords:
# 여러차례 (0.3953)
# 증언해 (0.3775)
# 달라며 (0.3775)
# 측근에 (0.3775)
# 전화 (0.3551)
# 김인섭 (0.3099)
# 재판 (0.2943)
# 단독 (0.2380)
# 이재명 (0.2254)
# 뒤처진 (0.0000)
#
#
# Article 249 Top-10 keywords:
# 독자위원회 (0.3758)
# 덜어줄 (0.3758)
# 美반도체법 (0.3758)
# 기업부담 (0.3758)
# 제시를 (0.3758)
# 과제 (0.3180)
# 국회 (0.2576)
# 대응 (0.2541)
# 정부 (0.2488)
# 듀피젠트 (0.0000)
#
#
# Article 250 Top-10 keywords:
# 우회 (0.3548)
# 해킹코드 (0.3548)
# 질문하자 (0.3548)
# 술술 (0.3388)
# 악용 (0.3388)
# 내놔 (0.3275)
# 챗gpt (0.2955)
# 범죄 (0.2914)
# 우려 (0.2603)
# 단독 (0.2136)
#
#
# Article 251 Top-10 keywords:
# 스쾃의 (0.3536)
# 홍란 (0.3536)
# 10km (0.3536)
# 달리기와 (0.3536)
# 인생홈런 (0.3536)
# 강철체력 (0.3536)
# 1000라운드 (0.3536)
# 이헌재의 (0.3536)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 252 Top-10 keywords:
# 주말집회에 (0.3599)
# 확성기 (0.3599)
# 95db (0.3599)
# 소음전광판 (0.3599)
# 사용중지 (0.3599)
# 넘자 (0.3599)
# 명령 (0.3437)
# 등장 (0.3233)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 253 Top-10 keywords:
# 찾을 (0.4189)
# 450만명 (0.4189)
# 진해군항제 (0.4189)
# 일찍 (0.4189)
# 벚꽃 (0.3252)
# 최다 (0.3222)
# 역대 (0.2978)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 254 Top-10 keywords:
# 건사피장 (0.3322)
# 사이에 (0.3322)
# 임희윤 (0.3322)
# 멜로디 (0.3322)
# 피어난 (0.3322)
# 죽기전 (0.3322)
# 하이브 (0.3172)
# 기자의 (0.3172)
# 건물 (0.2810)
# sm (0.2405)
#
#
# Article 255 Top-10 keywords:
# 담수화 (0.4234)
# 저수율 (0.4234)
# 목타는 (0.4234)
# 끌어 (0.4234)
# 해수 (0.3803)
# 남부 (0.3718)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 256 Top-10 keywords:
# 안전하게 (0.5170)
# 자전거길 (0.5170)
# 달려요 (0.5170)
# 한강 (0.4451)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 257 Top-10 keywords:
# 폐쇄한 (0.4181)
# 불러 (0.4181)
# 김기용 (0.4181)
# 특파원칼럼 (0.4181)
# 놓고 (0.3312)
# 이재용 (0.3188)
# 기업 (0.2990)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 258 Top-10 keywords:
# 10일 (0.4454)
# 지난해보다 (0.4454)
# 개화 (0.4454)
# 먼저 (0.3972)
# 벚꽃 (0.3849)
# 경기 (0.3144)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 259 Top-10 keywords:
# 전면해제를 (0.6267)
# 토지거래허가구역 (0.5785)
# 송파구 (0.5221)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
#
#
# Article 260 Top-10 keywords:
# 50조 (0.3898)
# 미국으로 (0.3898)
# 천광암 (0.3898)
# 코인 (0.3722)
# 칼럼 (0.3598)
# 사기 (0.3423)
# 권도형 (0.2924)
# 피해 (0.2712)
# 뒷받침했다 (0.0000)
# 뒤따라야 (0.0000)
#
#
# Article 261 Top-10 keywords:
# 250억어치 (0.5430)
# 서울사랑상품권 (0.5186)
# 발행 (0.5012)
# 할인 (0.4302)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 262 Top-10 keywords:
# 이용객 (0.4885)
# 세계3위로 (0.4885)
# 1억명 (0.4885)
# 내년 (0.3870)
# 인천공항 (0.3664)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 263 Top-10 keywords:
# 미시시피 (0.5228)
# 강타한 (0.5228)
# 초대형 (0.4807)
# 토네이도 (0.4713)
# 드라마로 (0.0000)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 264 Top-10 keywords:
# 남아 (0.4030)
# 13개國만 (0.4030)
# 차이나머니 (0.4030)
# 온두라스도 (0.4030)
# 단교 (0.3539)
# 수교 (0.3539)
# 대만 (0.3160)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 265 Top-10 keywords:
# 聯政 (0.4687)
# 네타냐후에 (0.4476)
# 균열 (0.4326)
# 반기 (0.3849)
# 국방장관 (0.3638)
# 이스라엘 (0.3352)
# 둘러보니 (0.0000)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 266 Top-10 keywords:
# 그의 (0.3171)
# 개화시기 (0.3171)
# 벚꽃과 (0.3171)
# 예측 (0.3171)
# 1000곳 (0.3171)
# 진다 (0.3171)
# 피고 (0.3171)
# 1년은 (0.3171)
# 사람 (0.2730)
# 벚꽃명소 (0.2683)
#
#
# Article 267 Top-10 keywords:
# 검사에 (0.3615)
# 좌표 (0.3615)
# 지지층 (0.3615)
# 살해협박 (0.3615)
# 수사검사 (0.3615)
# 찍자 (0.3615)
# 편지 (0.3452)
# 트럼프 (0.3112)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 268 Top-10 keywords:
# 컨설턴트들과 (0.3874)
# 알립니다 (0.3874)
# 트렌드 (0.3874)
# 함께하는 (0.3480)
# dbr (0.3480)
# 최고의 (0.3335)
# 아카데미 (0.3227)
# 부동산 (0.3037)
# 李대표 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 269 Top-10 keywords:
# 살림 (0.4561)
# 미니멀리즘의 (0.4561)
# 생활공작소 (0.4561)
# 원조 (0.4561)
# dbr (0.4097)
# 뒤처진 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 270 Top-10 keywords:
# 모색하길 (0.4053)
# 과학 (0.3741)
# dbr (0.3641)
# 하나 (0.3429)
# 국가 (0.3429)
# 가능성 (0.2935)
# 협력 (0.2917)
# 세계 (0.2835)
# 최고 (0.2765)
# 뒷동산 (0.0000)
#
#
# Article 271 Top-10 keywords:
# 이기려면 (0.3858)
# 기업별 (0.3858)
# 고유한 (0.3858)
# 확립해야 (0.3858)
# 인재상 (0.3858)
# ai를 (0.3684)
# dbr (0.3465)
# 드디어 (0.0000)
# 듀피젠트 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 272 Top-10 keywords:
# 동료가 (0.3198)
# 괴로운 (0.3198)
# 아프면 (0.3198)
# 공유한다 (0.3198)
# 아파 (0.3054)
# 물고기도 (0.3054)
# 감정 (0.2952)
# 느낄 (0.2873)
# 고통 (0.2873)
# 네가 (0.2808)
#
#
# Article 273 Top-10 keywords:
# 실현되나 (0.4266)
# 딥러닝 (0.4266)
# 고도화로 (0.4266)
# 똑똑해지는 (0.4266)
# 완전자율주행 (0.4266)
# ai (0.3000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 274 Top-10 keywords:
# 임대공급 (0.4188)
# 부지에 (0.4188)
# 브라이튼 (0.4188)
# 단신 (0.3866)
# mbc (0.3762)
# 여의도 (0.3167)
# 내달 (0.2871)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 275 Top-10 keywords:
# 공급사 (0.4689)
# gm (0.4689)
# 최우수 (0.4373)
# lg전자 (0.3754)
# 선정 (0.3516)
# 올해 (0.3232)
# 李대표 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 276 Top-10 keywords:
# 배터리팩 (0.3638)
# 안전도 (0.3638)
# 극한 (0.3638)
# 안깨져 (0.3638)
# 떨어져도 (0.3638)
# 5m (0.3638)
# 높이서 (0.3475)
# 검사 (0.2915)
# 뒷면에는 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 277 Top-10 keywords:
# 전력도매가 (0.3855)
# 박호정 (0.3855)
# 상한제론 (0.3855)
# 못해 (0.3682)
# 기고 (0.3463)
# 해결 (0.3385)
# 적자 (0.3126)
# 한전 (0.2939)
# 李대표 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 278 Top-10 keywords:
# 간절했던 (0.4374)
# 직원들 (0.4374)
# 비행 (0.4037)
# 날아오른 (0.4037)
# 이스타항공 (0.3929)
# 3년만에 (0.3701)
# 뒤처진 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 279 Top-10 keywords:
# 왕블루베리 (0.4582)
# 단단하고 (0.4582)
# 과육 (0.4582)
# 당도 (0.4375)
# 높은 (0.4229)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 280 Top-10 keywords:
# 해커톤 (0.3388)
# 33개팀 (0.3388)
# 경연 (0.3388)
# 시상 (0.3388)
# 종료 (0.3187)
# 본선 (0.3115)
# 양성 (0.2811)
# lg (0.2782)
# 인재 (0.2538)
# ai (0.2495)
#
#
# Article 281 Top-10 keywords:
# 장차관 (0.4159)
# 과기부 (0.4159)
# 협의체 (0.4159)
# 5년만에 (0.4159)
# 회의 (0.3519)
# 한일 (0.3416)
# 추진 (0.2597)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 282 Top-10 keywords:
# 낮춰 (0.4143)
# 3개월 (0.3957)
# 보증금 (0.3825)
# 전세 (0.3722)
# 67 (0.3638)
# 전보다 (0.3506)
# 아파트 (0.2946)
# 서울 (0.2119)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 283 Top-10 keywords:
# 韓만 (0.3501)
# 대우조선 (0.3501)
# 길어져 (0.3501)
# 안내놔 (0.3501)
# 결합 (0.3343)
# 공정위 (0.3343)
# 한화 (0.3232)
# 입장 (0.3014)
# 침묵 (0.3014)
# 李대표 (0.0000)
#
#
# Article 284 Top-10 keywords:
# 상어 (0.4561)
# 과감한 (0.4561)
# 포토존 (0.4561)
# 포즈 (0.4561)
# 가능한 (0.4097)
# 두산은 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 285 Top-10 keywords:
# 바꾸세요 (0.4576)
# 대출로 (0.4370)
# 고금리 (0.4224)
# 2금융권 (0.4018)
# 신용대출 (0.3872)
# 은행 (0.3314)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 286 Top-10 keywords:
# 공개매수서 (0.4227)
# 지분 (0.3902)
# 최대주주 (0.3797)
# 올라 (0.3639)
# 35 (0.3314)
# 카카오 (0.3124)
# sm (0.3061)
# 확보 (0.3023)
# 뒷받침했다 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 287 Top-10 keywords:
# 푼다 (0.4355)
# 할인쿠폰 (0.4159)
# 숙박 (0.4020)
# 내수 (0.3912)
# 대책 (0.3414)
# 이번주 (0.3381)
# 발표 (0.3030)
# 李대표 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 288 Top-10 keywords:
# 55억 (0.3785)
# 순익 (0.3785)
# 반토막에도 (0.3785)
# 증권사 (0.3614)
# 연봉 (0.3202)
# 늘어 (0.3069)
# 54 (0.2998)
# 임원 (0.2938)
# 최고 (0.2582)
# 드디어 (0.0000)
#
#
# Article 289 Top-10 keywords:
# 슈퍼에선 (0.4988)
# 생맥주 (0.4988)
# 안돼 (0.4294)
# 편의점 (0.4220)
# 판매 (0.3741)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 290 Top-10 keywords:
# 訪中 (0.4613)
# 사업장 (0.4159)
# 3년만에 (0.4087)
# 현지 (0.4024)
# 점검 (0.3869)
# 이재용 (0.3683)
# 듀엣곡 (0.0000)
# 뒷불 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 291 Top-10 keywords:
# 3조 (0.3727)
# 보폭 (0.3727)
# 5조 (0.3559)
# 넓힌다 (0.3559)
# k배터리 (0.3440)
# 7조 (0.3272)
# lg (0.2922)
# 삼성 (0.2867)
# 투자 (0.2754)
# 드라마 (0.0000)
#
#
# Article 292 Top-10 keywords:
# 통합공공임대주택 (0.4092)
# 1134채 (0.4092)
# 기장군에 (0.4092)
# 2025년 (0.3777)
# 부산지역 (0.3777)
# 준공 (0.3278)
# 계획 (0.3241)
# 뒤처진 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 293 Top-10 keywords:
# 하동군 (0.4561)
# 야간조명 (0.4561)
# 십리벚꽃길 (0.4561)
# 밝힌다 (0.4561)
# 화려한 (0.4097)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 294 Top-10 keywords:
# 미래비전 (0.3909)
# 제시할 (0.3909)
# 지방의 (0.3909)
# 초대석 (0.3733)
# 균형발전 (0.3733)
# 실효성 (0.3609)
# 있는 (0.2680)
# 위한 (0.2463)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 295 Top-10 keywords:
# 3만여명 (0.4840)
# 공개행사에 (0.4840)
# 순천만국제정원박람회 (0.4622)
# 참석 (0.4095)
# 사전 (0.3877)
# 뒤쪽의 (0.0000)
# 뒤늦은 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 296 Top-10 keywords:
# 5일간 (0.4964)
# 정읍 (0.4964)
# 31일부터 (0.4582)
# 벚꽃축제 (0.4459)
# 개최 (0.3137)
# 뒷면에는 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 297 Top-10 keywords:
# 가나 (0.4005)
# 치열 (0.4005)
# 전남북 (0.4005)
# 유치전 (0.4005)
# 국립마한센터 (0.3825)
# 어디로 (0.3825)
# 광주 (0.2565)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 298 Top-10 keywords:
# 춘천서 (0.5102)
# 통일플러스센터 (0.4691)
# 강원도 (0.4450)
# 착공 (0.4331)
# 오늘 (0.3662)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 299 Top-10 keywords:
# 55곳 (0.4650)
# 천안시 (0.4650)
# 빵집 (0.4441)
# 빵빵데이 (0.4177)
# 참여 (0.3307)
# 개최 (0.2939)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 300 Top-10 keywords:
# 평화누리호 (0.5008)
# 파로호 (0.5008)
# 유람선 (0.4499)
# 운항 (0.4113)
# 재개 (0.3561)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 301 Top-10 keywords:
# 출근하고 (0.3798)
# 바다로 (0.3798)
# ...
# 러브라인 (0.3397)
# 김은숙 (0.3397)
# 전한 (0.3397)
# 하도영 (0.3397)
# 글로리 (0.3124)
# 작가가 (0.3063)
# 진짜 (0.3063)
# 뒷받침했다 (0.0000)
#
#
# Article 5908 Top-10 keywords:
# 국수본부장에 (0.3944)
# 예정 (0.3903)
# 출신 (0.3829)
# 발표 (0.3464)
# 공식 (0.3413)
# 오늘 (0.3413)
# 우종수 (0.3351)
# 경찰 (0.2833)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5909 Top-10 keywords:
# 유가족에 (0.3858)
# 가서 (0.3755)
# 사과 (0.3389)
# 예정 (0.3277)
# 귀국 (0.3277)
# 손자 (0.2893)
# 전두환 (0.2879)
# 28일 (0.2879)
# 한국 (0.2642)
# 18 (0.2474)
#
#
# Article 5910 Top-10 keywords:
# 빌라서 (0.3794)
# 새벽 (0.3620)
# 국적 (0.3530)
# 어린이 (0.3491)
# 숨져 (0.3332)
# 4명 (0.3116)
# 안산 (0.3066)
# 오늘 (0.3021)
# 나이지리아 (0.2917)
# 뒤쪽의 (0.0000)
#
#
# Article 5911 Top-10 keywords:
# 있슈 (0.3575)
# 하나만 (0.3414)
# 기르자 (0.3414)
# 도시락 (0.3414)
# 첫째 (0.3300)
# 낳아 (0.3212)
# 비중 (0.3078)
# 출생아 (0.3025)
# 역대 (0.2542)
# 최고 (0.2439)
#
#
# Article 5912 Top-10 keywords:
# 등판한 (0.3457)
# 면세점 (0.3457)
# 롯데면세점 (0.3457)
# 핫코노미 (0.3457)
# 전쟁 (0.3301)
# 간다 (0.3191)
# 인천공항서 (0.2976)
# 명품 (0.2925)
# 까지 (0.2803)
# 대통령 (0.2418)
#
#
# Article 5913 Top-10 keywords:
# 했더니 (0.3646)
# 술값 (0.3646)
# 생수 (0.3482)
# 햄버거 (0.3366)
# 들썩 (0.3275)
# 진정되나 (0.3275)
# 줄줄이 (0.3201)
# 물가 (0.3085)
# 치킨 (0.2956)
# 뒷말 (0.0000)
#
#
# Article 5914 Top-10 keywords:
# 단원 (0.3854)
# 연극 (0.3854)
# 잡고 (0.3751)
# 지하철에 (0.3666)
# 보니 (0.3429)
# 나타났다 (0.3345)
# 신고 (0.3212)
# 남성 (0.3085)
# 뒤처진 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5915 Top-10 keywords:
# 반가움 (0.3575)
# 덕출 (0.3575)
# 안일권 (0.3575)
# 김준호 (0.3575)
# 군단 (0.3575)
# 신스틸러 (0.3575)
# 웅남이 (0.3414)
# 가득 (0.3414)
# 李대표 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 5916 Top-10 keywords:
# 방불케 (0.4237)
# 생지옥 (0.4237)
# 사체에 (0.4237)
# 무덤까지 (0.4237)
# 동물학대 (0.4047)
# 현장 (0.3435)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5917 Top-10 keywords:
# 등반한 (0.3540)
# 2300m (0.3540)
# 정장 (0.3540)
# 사연이 (0.3540)
# 차려입고 (0.3540)
# 클라스 (0.3380)
# 어떤 (0.3180)
# 월드 (0.2995)
# 남성 (0.2616)
# 뒤처진 (0.0000)
#
#
# Article 5918 Top-10 keywords:
# 박지훈의 (0.4634)
# 스케줄 (0.4634)
# 발매하는 (0.4634)
# 미니앨범 (0.4634)
# 번째 (0.3757)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5919 Top-10 keywords:
# 김광석 (0.3141)
# 오늘도 (0.3141)
# 겸임교수 (0.3141)
# 마시지만 (0.3141)
# 투자하자 (0.3141)
# 드셨죠 (0.3141)
# 클라스 (0.2999)
# 한양대 (0.2999)
# 커피 (0.2758)
# 말고 (0.2758)
#
#
# Article 5920 Top-10 keywords:
# 김진성 (0.3165)
# 365일 (0.3165)
# 입문부터 (0.3165)
# 소장 (0.3165)
# 실전까지 (0.3165)
# 상클 (0.3022)
# 필요해 (0.3022)
# 라이프 (0.2843)
# 육아 (0.2843)
# 아빠가 (0.2843)
#
#
# Article 5921 Top-10 keywords:
# 송하예 (0.4198)
# 듀엣곡 (0.4198)
# 키야엔터와 (0.4198)
# 발매 (0.3686)
# 손잡고 (0.3686)
# 도약 (0.3497)
# 4월 (0.2779)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5922 Top-10 keywords:
# 채수빈 (0.3996)
# 행복한 (0.3996)
# 셰익스피러 (0.3996)
# 러브 (0.3996)
# 시간이었다 (0.3996)
# 종연 (0.3996)
# 서울 (0.2044)
# 李대표 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5923 Top-10 keywords:
# 김사부 (0.4639)
# 시즌3 (0.4639)
# 낭만닥터 (0.4364)
# 방송 (0.4047)
# 28일 (0.3346)
# 4월 (0.3216)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5924 Top-10 keywords:
# 완벽하게 (0.4053)
# 뱀뱀 (0.4053)
# 본업 (0.4053)
# 차린 (0.4053)
# 대세 (0.4053)
# 하루 (0.3329)
# 공개 (0.2605)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5925 Top-10 keywords:
# 라포엠 (0.4399)
# 투어의 (0.4399)
# 올린 (0.4201)
# 화려한 (0.3952)
# 공연 (0.3863)
# 전국 (0.2837)
# 서울 (0.2250)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5926 Top-10 keywords:
# 높이는 (0.3599)
# 무드 (0.3599)
# 스타일링 (0.3599)
# 이채연 (0.3599)
# 극과 (0.3599)
# 하이틴 (0.3599)
# 기대감 (0.3437)
# 컴백 (0.3233)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5927 Top-10 keywords:
# 밀입국한 (0.4668)
# 카자흐스탄인 (0.4019)
# 울타리 (0.3950)
# 인천공항 (0.3501)
# 넘어 (0.3450)
# 검거 (0.3339)
# 20대 (0.3339)
# 둘러보니 (0.0000)
# 듀엣곡 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5928 Top-10 keywords:
# ㅣ리얼미터 (0.4383)
# 평가는 (0.4186)
# 부정 (0.4046)
# 61 (0.3773)
# 지지율 (0.3553)
# 36 (0.3262)
# 대통령 (0.3065)
# 두자릿수 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5929 Top-10 keywords:
# 4종 (0.4840)
# 출석 (0.3836)
# 투약 (0.3823)
# 마약 (0.3533)
# 혐의 (0.3492)
# 경찰 (0.3397)
# 유아인 (0.3320)
# 둘러보고 (0.0000)
# 뒷면에는 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5930 Top-10 keywords:
# 말도 (0.5021)
# 없었다 (0.4853)
# 아무 (0.4723)
# 출석 (0.3379)
# 경찰 (0.2992)
# 유아인 (0.2924)
# 듀엣곡 (0.0000)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5931 Top-10 keywords:
# 신곡 (0.3640)
# 블랙핑크 (0.3518)
# 가사 (0.3518)
# 향기만 (0.3518)
# 갔단다 (0.3518)
# 지수 (0.3424)
# 남기고 (0.3281)
# 일부 (0.2959)
# 공개 (0.2449)
# 李대표 (0.0000)
#
#
# Article 5932 Top-10 keywords:
# 서울경찰청 (0.4597)
# 출석 (0.4225)
# 투약 (0.4210)
# 마약 (0.3891)
# 혐의 (0.3846)
# 유아인 (0.3656)
# 둘러보고 (0.0000)
# 뒤에 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5933 Top-10 keywords:
# 화난다 (0.4561)
# 루머에 (0.4356)
# 여자친구 (0.4210)
# 매우 (0.3799)
# 엑소 (0.3746)
# 세훈 (0.3746)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 5934 Top-10 keywords:
# 고강도 (0.4167)
# 귀가 (0.3831)
# 잘못된 (0.3831)
# 빠져 (0.3538)
# 12시간 (0.3421)
# 조사 (0.2900)
# 종합 (0.2845)
# 마약 (0.2583)
# 유아인 (0.2427)
# 뒤쪽의 (0.0000)
#
#
# Article 5935 Top-10 keywords:
# 자기 (0.3866)
# 마친 (0.3737)
# 합리화 (0.3637)
# 잘못된 (0.3555)
# 늪에 (0.3372)
# 사과 (0.3282)
# 빠져 (0.3282)
# 조사 (0.2691)
# 유아인 (0.2251)
# 李대표 (0.0000)
#
#
# Article 5936 Top-10 keywords:
# 김모씨 (0.4558)
# 사업가 (0.3924)
# 알선 (0.3744)
# 기각 (0.3539)
# 위증 (0.3301)
# 백현동 (0.3140)
# 구속영장 (0.3068)
# 혐의 (0.2667)
# 둘러싼 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 5937 Top-10 keywords:
# 검토 (0.4327)
# 구속영장 (0.4072)
# 조사 (0.4021)
# 마약 (0.3581)
# 혐의 (0.3539)
# 경찰 (0.3443)
# 유아인 (0.3365)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5938 Top-10 keywords:
# 방청 (0.3962)
# 최파타 (0.3784)
# 팬데믹 (0.3559)
# 방탄소년단 (0.3479)
# 출연 (0.3411)
# 지민 (0.3352)
# 이후 (0.2801)
# 31일 (0.2729)
# 모집 (0.2655)
# 동아쏘시오그룹 (0.0000)
#
#
# Article 5939 Top-10 keywords:
# 실무 (0.4713)
# 김민석 (0.3821)
# 정책위의장 (0.3734)
# 유임 (0.3695)
# 총선 (0.3659)
# 사무총장 (0.3659)
# 민주당 (0.2970)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5940 Top-10 keywords:
# 에이프릴 (0.3636)
# 좋아 (0.3636)
# 웹드 (0.3636)
# 이대로가 (0.3472)
# 이현주 (0.3472)
# 주연 (0.3266)
# 지금 (0.3076)
# 발탁 (0.2880)
# 출신 (0.2796)
# 뒷받침 (0.0000)
#
#
# Article 5941 Top-10 keywords:
# 산불에 (0.3806)
# 사찰 (0.3806)
# 가슴 (0.3806)
# 1000년 (0.3806)
# 쓸어 (0.3635)
# 정수사 (0.3419)
# 내린 (0.3277)
# 마니산 (0.2530)
# 李대표 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5942 Top-10 keywords:
# 20일부터 (0.4525)
# 장기하 (0.4525)
# 6회 (0.4322)
# 공연 (0.3973)
# 4월 (0.2996)
# 개최 (0.2860)
# 단독 (0.2725)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5943 Top-10 keywords:
# 팬들과 (0.4428)
# 카운트다운 (0.4428)
# 지수 (0.3977)
# 라이브 (0.3977)
# 발매 (0.3888)
# 앨범 (0.3746)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 5944 Top-10 keywords:
# 채운 (0.4553)
# 9000석 (0.4553)
# 찬또배기 (0.4553)
# 사흘간 (0.4348)
# 이찬원 (0.4348)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5945 Top-10 keywords:
# 한달여 (0.5080)
# 경기남부경찰청장 (0.4374)
# 국수본부장에 (0.4025)
# 낙마 (0.4025)
# 우종수 (0.3420)
# 정순신 (0.3312)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
# 뒷동산서 (0.0000)
# 뒷말 (0.0000)
#
#
# Article 5946 Top-10 keywords:
# 트로트 (0.4091)
# 가수로 (0.4091)
# 김용필 (0.3907)
# 미스터트롯2 (0.3907)
# 아나운서 (0.3907)
# 아닌 (0.3408)
# 출발 (0.3023)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5947 Top-10 keywords:
# 검찰수사로 (0.4325)
# 공익 (0.4325)
# 증진 (0.3885)
# 중요해져 (0.3798)
# 검수원복 (0.3298)
# 국민 (0.3132)
# 위해 (0.2585)
# 한동훈 (0.2388)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5948 Top-10 keywords:
# 곤욕 (0.3698)
# 루머로 (0.3531)
# 목격담 (0.3531)
# 산부인과 (0.3531)
# 사실 (0.3413)
# 허위 (0.3413)
# 세훈 (0.3037)
# 엑소 (0.3037)
# sm (0.2678)
# 뒷받침 (0.0000)
#
#
# Article 5949 Top-10 keywords:
# 싶어 (0.4298)
# 풀어드리고 (0.4043)
# 도움 (0.3874)
# 요청 (0.3565)
# 피해자 (0.3326)
# 손자 (0.3115)
# 전두환 (0.3100)
# 18 (0.2664)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5950 Top-10 keywords:
# 티저 (0.4561)
# 기대되는 (0.4561)
# 빌리 (0.4561)
# 공개될수록 (0.4561)
# 컴백 (0.4097)
# 뒷받침 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5951 Top-10 keywords:
# 득남 (0.4599)
# 사업가와 (0.4445)
# 장미인애 (0.4326)
# 결혼식 (0.3956)
# 29일 (0.3815)
# 4월 (0.3188)
# 뒷동산서 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5952 Top-10 keywords:
# 관장 (0.4026)
# 30억원 (0.3787)
# 제기 (0.3512)
# 위자료 (0.3273)
# 동거인에 (0.3273)
# 노소영 (0.3115)
# 최태원 (0.3073)
# 소송 (0.3053)
# 회장 (0.2691)
# 뒷받침 (0.0000)
#
#
# Article 5953 Top-10 keywords:
# 발판된 (0.3864)
# 해외팬 (0.3864)
# 43만 (0.3864)
# 월드투어 (0.3567)
# 에이티즈 (0.3567)
# 인터뷰 (0.3219)
# 성장 (0.3133)
# 만난 (0.3096)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5954 Top-10 keywords:
# 많았기 (0.3488)
# 시기에 (0.3488)
# 때문 (0.3331)
# 배달 (0.3063)
# 확산 (0.2951)
# 수요 (0.2951)
# 외식 (0.2865)
# 코로나 (0.2828)
# 가맹점 (0.2763)
# 증가 (0.2660)
#
#
# Article 5955 Top-10 keywords:
# 연대사 (0.3235)
# 두기로 (0.3235)
# 민주노총이 (0.3235)
# 방심위는 (0.3235)
# 심의 (0.2986)
# 국정원 (0.2906)
# 삭제 (0.2906)
# 공개한 (0.2906)
# 그냥 (0.2785)
# 요청 (0.2562)
#
#
# Article 5956 Top-10 keywords:
# 동아시아에 (0.3970)
# 절정 (0.3970)
# 벚나무가 (0.3970)
# 분포하는 (0.3970)
# 워싱턴dc에 (0.3970)
# 이슈 (0.3418)
# 벚꽃 (0.3082)
# 李대표 (0.0000)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5957 Top-10 keywords:
# 목사가 (0.4425)
# 미국서 (0.4068)
# 최고위원 (0.3712)
# 전광훈 (0.3671)
# 우파 (0.3503)
# 천하통일 (0.3503)
# 김재원 (0.3475)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5958 Top-10 keywords:
# 자취 (0.3951)
# 감췄던 (0.3951)
# 항저우서 (0.3951)
# 포착 (0.3549)
# 알리바바 (0.3469)
# 마윈 (0.3291)
# 매체 (0.3245)
# 중국 (0.2683)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5959 Top-10 keywords:
# 유재석 (0.4144)
# 싹쓰리부터 (0.4144)
# 주주시크릿까지 (0.4144)
# 불패 (0.4144)
# 이어간다 (0.3957)
# 음원 (0.3957)
# 듀피젠트 (0.0000)
# 뒤쪽의 (0.0000)
# 드라마 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5960 Top-10 keywords:
# 인정할까 (0.4594)
# 조사중 (0.4594)
# 7시간째 (0.4594)
# 출석 (0.2952)
# 마약 (0.2719)
# 혐의 (0.2688)
# 경찰 (0.2614)
# 유아인 (0.2555)
# 뒷불 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 5961 Top-10 keywords:
# 산행 (0.3680)
# 만지지 (0.3515)
# 광견병 (0.3515)
# 살포 (0.3515)
# 야생동물 (0.3397)
# 백신 (0.3306)
# 이것 (0.3232)
# 마세요 (0.3232)
# 서울시 (0.2456)
# 뒷동산서 (0.0000)
#
#
# Article 5962 Top-10 keywords:
# 반전의 (0.4496)
# 거듭하는 (0.4496)
# 신곡리뷰 (0.4496)
# 키치 (0.4039)
# 아이브 (0.4039)
# 반전 (0.2596)
# 드라이브 (0.0000)
# 뒷받침했다 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5963 Top-10 keywords:
# 뉴스레터600 (0.4669)
# jtbc (0.4458)
# 재가 (0.4458)
# 버린 (0.4458)
# 코리안드림 (0.4309)
# 李대표 (0.0000)
# 뒷면에는 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5964 Top-10 keywords:
# 주도한 (0.4318)
# 야당이 (0.4318)
# 모아 (0.3717)
# 양곡관리법 (0.3352)
# 의견 (0.3239)
# 당정 (0.3088)
# 대통령 (0.3020)
# 대응 (0.2919)
# 뒷말 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5965 Top-10 keywords:
# 패륜아 (0.4104)
# 건국절 (0.4104)
# 재조명 (0.4104)
# 낙인 (0.3919)
# 재점화 (0.3788)
# 이승만 (0.3370)
# 논란 (0.2901)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5966 Top-10 keywords:
# 탄핵심판 (0.4161)
# 않겠다 (0.3973)
# 불복하나 (0.3973)
# 피하지 (0.3373)
# vs (0.3032)
# 민주 (0.2958)
# 헌재 (0.2895)
# 결정 (0.2852)
# 한동훈 (0.2297)
# 뒷동산서 (0.0000)
#
#
# Article 5967 Top-10 keywords:
# 계륵의 (0.4705)
# 딜레마 (0.4493)
# 개혁의 (0.4493)
# 빠진 (0.3919)
# 개딸 (0.3652)
# 민주당 (0.2964)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
# 드라마로 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5968 Top-10 keywords:
# 생각은 (0.5346)
# 여러분의 (0.5346)
# 개딸 (0.4150)
# 논란 (0.3779)
# 민주당 (0.3368)
# 드라마화 (0.0000)
# 뒷받침 (0.0000)
# 뒤쪽의 (0.0000)
# 뒤처진 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5969 Top-10 keywords:
# 우파를 (0.4805)
# 발언 (0.3849)
# 전광훈 (0.3806)
# 천하통일 (0.3633)
# 김재원 (0.3604)
# 논란 (0.3397)
# 미국 (0.3144)
# 드디어 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5970 Top-10 keywords:
# 담임은 (0.3675)
# 깊은 (0.3675)
# 상담일지 (0.3675)
# 장난을 (0.3301)
# 학폭으로 (0.3061)
# 몰아 (0.3061)
# 보니 (0.3018)
# 반성 (0.2979)
# 아들 (0.2474)
# 정순신 (0.2396)
#
#
# Article 5971 Top-10 keywords:
# 은행 (0.6160)
# 주인은 (0.4253)
# 실리콘밸리 (0.3926)
# 파산한 (0.3821)
# 퍼스트시티즌스 (0.3735)
# 듀피젠트 (0.0000)
# 뒷동산서 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5972 Top-10 keywords:
# 대책인가 (0.3863)
# 누구를 (0.3863)
# 무늬만 (0.3863)
# 인적 (0.3689)
# 뉴스룸 (0.3689)
# 쇄신 (0.3470)
# 저출산 (0.3172)
# 위한 (0.2434)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5973 Top-10 keywords:
# 사업장에 (0.4145)
# 보급 (0.4145)
# 소규모 (0.3866)
# 근로시간 (0.3866)
# 검토 (0.3212)
# 기록 (0.3049)
# 정부 (0.2972)
# 단독 (0.2704)
# 두자릿수 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 5974 Top-10 keywords:
# 들어보니 (0.3710)
# 분단위 (0.3710)
# 막을 (0.3543)
# 공짜 (0.3425)
# 직장인 (0.3425)
# 야근 (0.3333)
# 감시 (0.3194)
# 의견 (0.2783)
# 우려 (0.2722)
# 뒷받침 (0.0000)
#
#
# Article 5975 Top-10 keywords:
# 김민정 (0.3719)
# 어렵고 (0.3719)
# 있더라 (0.3719)
# 고통스러운 (0.3719)
# 끝낸 (0.3551)
# 소속사 (0.3340)
# 순간 (0.3265)
# 분쟁 (0.3202)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5976 Top-10 keywords:
# 재가 (0.4399)
# 코리안드림 (0.4252)
# 다세대주택 (0.4044)
# 숨진 (0.3734)
# 화재로 (0.3482)
# 4남매 (0.3294)
# 나이지리아 (0.3049)
# 李대표 (0.0000)
# 뒷동산서 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5977 Top-10 keywords:
# 격리 (0.3826)
# 확진자 (0.3826)
# 5일 (0.3723)
# 일상회복 (0.3568)
# 로드맵 (0.3568)
# 7일 (0.3568)
# 이번주 (0.3218)
# 발표 (0.2884)
# 뒷받침했다 (0.0000)
# 뒷받침 (0.0000)
#
#
# Article 5978 Top-10 keywords:
# 빠져나오지 (0.4063)
# 웃던 (0.4063)
# 아이인데 (0.4063)
# 화상에도 (0.4063)
# 못했다 (0.3750)
# 2년 (0.3185)
# 이번엔 (0.3125)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5979 Top-10 keywords:
# 서로 (0.4513)
# 사과하라 (0.4210)
# 검수완박법 (0.3964)
# 놓고 (0.3874)
# 충돌 (0.3796)
# 민주당 (0.3081)
# 한동훈 (0.2700)
# 드디어 (0.0000)
# 뒷말 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5980 Top-10 keywords:
# 없었는데 (0.4019)
# 지워진 (0.4019)
# 장난을 (0.3610)
# 학폭으로 (0.3348)
# 몰아 (0.3348)
# 반성 (0.3258)
# 기록 (0.2729)
# 아들 (0.2705)
# 정순신 (0.2620)
# 李대표 (0.0000)
#
#
# Article 5981 Top-10 keywords:
# 위안부는 (0.3721)
# 램지어 (0.3721)
# 책에서도 (0.3721)
# 출간할 (0.3721)
# 매춘부 (0.3721)
# 새로 (0.3342)
# 왜곡 (0.3203)
# 주장 (0.3056)
# 李대표 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 5982 Top-10 keywords:
# 시늉뿐인 (0.4429)
# 공천 (0.3978)
# 당직개편 (0.3689)
# 사무총장은 (0.3689)
# 그대로 (0.3638)
# 핵심 (0.3591)
# 비명계 (0.3348)
# 李대표 (0.0000)
# 뒷말 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5983 Top-10 keywords:
# 적자인데 (0.3898)
# 30조 (0.3898)
# 다닌 (0.3598)
# 자회사 (0.3422)
# 외유성 (0.3056)
# 출장 (0.3056)
# 임원 (0.3026)
# 한전 (0.2972)
# 해외 (0.2880)
# 뒤쪽의 (0.0000)
#
#
# Article 5984 Top-10 keywords:
# 정상급 (0.3907)
# 74년 (0.3802)
# 도착 (0.3581)
# 총통 (0.3477)
# 대만 (0.3318)
# 마잉주 (0.3286)
# 방문 (0.3065)
# 중국 (0.2875)
# 만에 (0.2429)
# 뒷말 (0.0000)
#
#
# Article 5985 Top-10 keywords:
# 해상훈련 (0.3934)
# 위의 (0.3828)
# 군사기지 (0.3742)
# 모습 (0.3669)
# 바다 (0.3606)
# 핵항모 (0.3341)
# 니미츠함 (0.3278)
# 공개 (0.2739)
# 둘러봤다 (0.0000)
# 뒷받침 (0.0000)
#
#
# Article 5986 Top-10 keywords:
# 허가된 (0.3800)
# 번호표 (0.3800)
# 목에 (0.3800)
# 홍콩보안법 (0.3800)
# 걸린 (0.3800)
# 시민들 (0.3508)
# 시위 (0.2873)
# 이후 (0.2687)
# 드디어 (0.0000)
# 뒤처진 (0.0000)
#
#
# Article 5987 Top-10 keywords:
# 3국 (0.3976)
# 결정은 (0.3976)
# 법원의 (0.3976)
# 신경전 (0.3976)
# 신병확보 (0.3797)
# 몬테네그로 (0.3670)
# 권도형 (0.2982)
# 뒷동산 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5988 Top-10 keywords:
# 원본 (0.4197)
# cctv (0.3874)
# 근무 (0.3613)
# 60대 (0.3613)
# 금감원 (0.3613)
# 숨진 (0.3403)
# 가장 (0.3200)
# 단독 (0.2527)
# 뒷받침 (0.0000)
# 뒷동산 (0.0000)
#
#
# Article 5989 Top-10 keywords:
# 장소 (0.3689)
# 유품은 (0.3689)
# 공개도 (0.3523)
# 뒤늦게 (0.3523)
# 먹지 (0.3523)
# 못한 (0.3314)
# 받은 (0.3121)
# 거부 (0.3073)
# 사망 (0.2317)
# 듀피젠트 (0.0000)
#
#
# Article 5990 Top-10 keywords:
# 그리움에 (0.4400)
# 사무쳐 (0.4400)
# 유족들 (0.4202)
# 진실버스 (0.3864)
# 오른 (0.3327)
# 참사 (0.2975)
# 이태원 (0.2962)
# 뒷동산서 (0.0000)
# 뒤에도 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5991 Top-10 keywords:
# 갯벌의 (0.3763)
# 새만금 (0.3763)
# 밀착카메라 (0.3763)
# 간척 (0.3763)
# 생명들 (0.3763)
# 남은 (0.3380)
# 30년 (0.3134)
# 마지막 (0.2822)
# 李대표 (0.0000)
# 뒷받침했다 (0.0000)
#
#
# Article 5992 Top-10 keywords:
# 여자들 (0.4011)
# 막말 (0.4011)
# 저하 (0.4011)
# 대학강사 (0.4011)
# 학력 (0.4011)
# 쏟아낸 (0.3703)
# 단독 (0.2416)
# 들썩일 (0.0000)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5993 Top-10 keywords:
# 목사께서 (0.4437)
# 발언 (0.3851)
# 전광훈 (0.3808)
# 우파 (0.3635)
# 천하통일 (0.3635)
# 김재원 (0.3606)
# 논란 (0.3399)
# 드라마 (0.0000)
# 뒷말 (0.0000)
# 뒤쪽의 (0.0000)
#
#
# Article 5994 Top-10 keywords:
# 클럽으로 (0.4363)
# 퍼진 (0.4363)
# 상자 (0.4363)
# 하와이서 (0.3831)
# 과자 (0.3692)
# 전국 (0.2814)
# 마약 (0.2582)
# 뒤쪽의 (0.0000)
# 뒤따라야 (0.0000)
# 뒤로 (0.0000)
#
#
# Article 5995 Top-10 keywords:
# 응원의 (0.4023)
# 스타된 (0.4023)
# 봇물 (0.3613)
# 패러디 (0.3532)
# 이슈 (0.3463)
# 세로 (0.3463)
# 얼룩말 (0.3304)
# 글로벌 (0.2685)
# 뒷받침 (0.0000)
# 뒷면에는 (0.0000)
#
#
# Article 5996 Top-10 keywords:
# 면제 (0.5626)
# 다시보기 (0.3623)
# 박성태의 (0.3623)
# 증여세 (0.3460)
# 낳으면 (0.3255)
# 병역 (0.3182)
# 자녀 (0.3066)
# 뒷말 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5997 Top-10 keywords:
# 1순위 (0.4353)
# 리턴매치 (0.4207)
# 경계 (0.4095)
# 우루과이와 (0.4095)
# 발베르데 (0.3924)
# 클린스만호 (0.3797)
# 듀엣곡 (0.0000)
# 드라마 (0.0000)
# 드라마로 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 5998 Top-10 keywords:
# 115위의 (0.3725)
# 끝이다 (0.3725)
# 싶을 (0.3725)
# 골들 (0.3725)
# 반격 (0.3438)
# 화려한 (0.3346)
# 유로 (0.3346)
# 예선 (0.3207)
# 뒷면에는 (0.0000)
# 뒤에서 (0.0000)
#
#
# Article 5999 Top-10 keywords:
# 팬들 (0.4659)
# 환호 (0.4449)
# 메달 (0.4300)
# 금의환향 (0.3777)
# 세계선수권 (0.3652)
# 차준환 (0.3522)
# 뒷동산 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 6000 Top-10 keywords:
# 투지 (0.3869)
# 벼랑 (0.3695)
# 역전 (0.3475)
# 펜싱 (0.3397)
# 단체전 (0.3397)
# 사브르 (0.3223)
# 월드컵 (0.3004)
# 남자 (0.2976)
# 우승 (0.2820)
# 뒷면에는 (0.0000)
#
#
# Article 6001 Top-10 keywords:
# 찍고 (0.3921)
# 더불어 (0.3921)
# 성장한 (0.3745)
# 수영 (0.3522)
# ag (0.3221)
# 황선우 (0.3179)
# 출전 (0.3016)
# 1위 (0.2663)
# 한국 (0.2479)
# 뒷말 (0.0000)
#
#
# Article 6002 Top-10 keywords:
# 장면 (0.4390)
# 시저스킥이 (0.4390)
# 이보다 (0.4390)
# 멋진 (0.4192)
# 있을까 (0.3943)
# 오늘 (0.3009)
# 뒤처진 (0.0000)
# 뒤로 (0.0000)
# 뒤에 (0.0000)
# 뒤에도 (0.0000)
#
#
# Article 6003 Top-10 keywords:
# 질환 (0.4084)
# 기상센터 (0.4084)
# 환절기 (0.3770)
# 포근 (0.3516)
# 봄철 (0.3402)
# 맑고 (0.3272)
# 주의 (0.3141)
# 28일 (0.2813)
# 뒤쪽의 (0.0000)
# 뒤늦은 (0.0000)
#
#
# Article 6004 Top-10 keywords:
# 드림은 (0.4315)
# 코리안 (0.4315)
# 불에 (0.4121)
# 없었다 (0.3983)
# 숨진 (0.3498)
# 4남매 (0.3086)
# 나이지리아 (0.2856)
# 듀피젠트 (0.0000)
# 드라마 (0.0000)
# 뒤에 (0.0000)
#
#
# Article 6005 Top-10 keywords:
# 마약혐의 (0.3882)
# 일탈 (0.3882)
# 합리화 (0.3651)
# 깊이 (0.3499)
# 했다 (0.3295)
# 반성 (0.3295)
# 12시간 (0.3187)
# 조사 (0.2702)
# 유아인 (0.2261)
# 뒷불 (0.0000)
#
#
# Article 6006 Top-10 keywords:
# 혐의 (0.4646)
# 울먹이며 (0.3970)
# 드디어 (0.3665)
# 열었다 (0.3418)
# 인정 (0.3307)
# 일부 (0.3082)
# 종합 (0.2588)
# 마약 (0.2350)
# 유아인 (0.2208)
# 뒷받침했다 (0.0000)

# %%
# TfidfVectorizer 초기화
tfidf_vectorizer = TfidfVectorizer()

# TF-IDF 계산
tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_titles)

# 전체 문서에 대한 각 단어의 TF-IDF 점수 합산
scores_sum = np.sum(tfidf_matrix, axis=0)

# 배열 형태로 변환
scores_sum_array = np.array(scores_sum).flatten()

# 피처 이름 가져오기
feature_names = np.array(tfidf_vectorizer.get_feature_names_out())

# 점수에 따라 내림차순으로 정렬하고 상위 N개의 인덱스 가져오기
top_n_indices = np.argsort(scores_sum_array)[::-1][:10]

# 상위 N개 키워드와 점수 출력
print("Top N Keywords:")
for index in top_n_indices:
    print(f"{feature_names[index]} ({scores_sum_array[index]:.4f})")
# Out:
# Top N Keywords:
# 급증 (112.9889)
# 매도잔량 (75.6027)
# 오르며 (57.0777)
# 체결강도 (57.0777)
# 매수잔량 (57.0368)
# 지속 (42.4047)
# 강세 (41.3144)
# 2023 (33.7808)
# 27 (30.4585)
# 03 (30.0200)

# %%
# 형태소 분석기 초기화
okt = Okt()

# 명사만 추출하는 함수
def get_nouns(text):
    nouns = okt.nouns(text)
    return [noun for noun in nouns if len(noun) > 2]  # 2글자 명사 제외

# TfidfVectorizer 초기화 (명사만 추출하여 사용)
tfidf_vectorizer = TfidfVectorizer(tokenizer=get_nouns, min_df=10)  # min_df는 최소 문서 빈도, 필요에 따라 조정

# TF-IDF 계산
tfidf_matrix = tfidf_vectorizer.fit_transform(cleaned_titles)  # cleaned_articles는 전처리된 뉴스 본문 리스트

# 전체 문서에 대한 각 단어의 TF-IDF 점수 합산
scores_sum = np.sum(tfidf_matrix, axis=0)

# 배열 형태로 변환
scores_sum_array = np.array(scores_sum).flatten()

# 피처 이름 가져오기
feature_names = np.array(tfidf_vectorizer.get_feature_names_out())

# 점수에 따라 내림차순으로 정렬하고 상위 N개의 인덱스 가져오기
top_n_indices = np.argsort(scores_sum_array)[::-1][:3]  # 상위 10개 키워드

# 상위 N개 키워드와 점수 출력
result = []
print("Top N Keywords:")
for index in top_n_indices:
    result.append(feature_names[index])
result
# Out:
# c:\Users\SSAFY\AppData\Local\Programs\Python\Python39\lib\site-packages\sklearn\feature_extraction\text.py:525: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
# Top N Keywords:
# ['유아인', '한동훈', '이재명']
