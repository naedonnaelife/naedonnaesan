# %%
import pandas as pd

# %%
df = pd.read_csv("매물 엔티티.csv")

# %%
df
# Out:
#        전월세구분  법정동명  보증금(만원)  임대료(만원)                             건물명   건물용도  \
# 0         전세    묵동    46000        0                           금호어울림    아파트
# 1         전세    묵동    46500        0                           금호어울림    아파트
# 2         월세  명륜3가     1000       85                        (1-1028)  연립다세대
# 3         월세   자곡동     5000       42  \t강남 푸르지오시티 2차(PRUGIO CITYⅡ)\t   오피스텔
# 4         월세   신사동     3000       50                         (1-103)  연립다세대
# ...      ...   ...      ...      ...                             ...    ...
# 166222    월세   신정동    50000      120               목동파크자이(101동~108동)    아파트
# 166223    월세   신정동     6296        8                         목동힐스테이트    아파트
# 166224    전세   신정동    70350        0                         목동힐스테이트    아파트
# 166225    월세   중계동      636        9                         목화(4단지)    아파트
# 166226    월세   시흥동     1000       50                             무지개    아파트
#
# ...

# %%
df.columns = ['building_type','dong_id', 'deposit', 'monthly_pay', 'name', 'building_type', 'floor', 'area', 'x', 'y', 'address']

# %%
df
# Out:
#        building_type dong_id  deposit  monthly_pay  \
# 0                 전세      묵동    46000            0
# 1                 전세      묵동    46500            0
# 2                 월세    명륜3가     1000           85
# 3                 월세     자곡동     5000           42
# 4                 월세     신사동     3000           50
# ...              ...     ...      ...          ...
# 166222            월세     신정동    50000          120
# 166223            월세     신정동     6296            8
# 166224            전세     신정동    70350            0
# 166225            월세     중계동      636            9
# 166226            월세     시흥동     1000           50
#
#                                   name building_type  floor    area  \
# 0                                금호어울림           아파트      3   84.71
# 1                                금호어울림           아파트      4  101.97
# 2                             (1-1028)         연립다세대      1   83.37
# 3       \t강남 푸르지오시티 2차(PRUGIO CITYⅡ)\t          오피스텔      2   19.97
# ...

# %%
df1 = pd.read_csv("군집 결과.csv", index_col=0)

# %%
df1.columns = ['dong_name', 'safety_cnt', 'leisure_cnt', 'food_cnt', 'health_cnt', 'conv_cnt', 'transp_cnt', 'cafe_cnt', 'pub_cnt','군집']

# %%
df1.drop(axis=1, columns=['군집']).to_csv('데이터 넣기용 동.csv', index=False)

# %%
merged_df.to_csv('편의시설 변경 버전.csv', index=False)
